# %% [markdown]
# # Environment Setup
#
# This notebook installs all required Python dependencies to run the project
# notebooks and the optional Streamlit-based user interface.

# %%
import sys
import subprocess

print("Installing project dependencies from requirements.txt...")

subprocess.check_call([
    sys.executable,
    "-m",
    "pip",
    "install",
    "-r",
    "../requirements.txt"
])

print("All dependencies installed successfully.")
# Out:
# Installing project dependencies from requirements.txt...
# ...
# All dependencies installed successfully.

# %%
import pandas as pd
import numpy as np
import sklearn
import joblib
import streamlit
import matplotlib
import seaborn
import scipy
import skopt
import category_encoders
import rapidfuzz

print("Environment ready.\n")

print("Versions:")
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("scikit-learn:", sklearn.__version__)
print("joblib:", joblib.__version__)
print("streamlit:", streamlit.__version__)
print("matplotlib:", matplotlib.__version__)
print("seaborn:", seaborn.__version__)
print("scipy:", scipy.__version__)
print("scikit-optimize:", skopt.__version__)
print("category-encoders:", category_encoders.__version__)
print("rapidfuzz:", rapidfuzz.__version__)
# Out:
# Environment ready.
#
# Versions:
# pandas: 2.2.3
# numpy: 2.1.3
# scikit-learn: 1.6.1
# joblib: 1.4.2
# streamlit: 1.45.1
# matplotlib: 3.10.0
# seaborn: 0.13.2
# scipy: 1.15.3
# scikit-optimize: 0.10.2
# category-encoders: 2.8.1
# rapidfuzz: 3.14.3
