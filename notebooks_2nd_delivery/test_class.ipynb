# %%
from utils.functions import *
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from Preprocessing_pipelines.Outliers_pipeline import OutliersDealer
from Preprocessing_pipelines.Missing_Values_pipeline import MissingValuesDealer
from Preprocessing_pipelines.Encoding_pipeline import EncodingDealer
from Preprocessing_pipelines.Scaling_pipeline import ScalingDealer
from Preprocessing_pipelines.Feature_Selection_pipeline import FeatureSelectionDealer
data = pd.read_csv("../data/data_cleaned.csv")
pd.set_option("display.max_columns", None)

# %%
data = data.sample(frac=1).reset_index(drop=True)

# %%
data
# Out:
#        carID     Brand     model  car_age  price transmission   mileage  \
# 0      43813  Mercedes   C class      5.0  27480    Semi-Auto   11408.0
# 1      37750  Mercedes   C class      7.0  14990    Semi-Auto   27424.0
# 2      12487       BMW        X3      7.0  20999    Semi-Auto   39181.0
# 3      40011  Mercedes   A class      NaN  26000    Semi-Auto    1000.0
# 4      63871      Opel    Meriva      7.0   6800       Manual   26601.0
# ...      ...       ...       ...      ...    ...          ...       ...
# 75968  53332    Toyota     Yaris      7.0  11500    Automatic   36167.0
# 75969   1274      Audi        A3      7.0  20990    Automatic   31376.0
# 75970  13304       BMW  8 series     16.0   4250    Automatic  141000.0
# 75971  30208      Ford     S-max     11.0   6899       Manual   31910.0
# 75972  33180   Hyundai    Tucson      5.0  15792       Manual   16449.0
#
#       fuelType         tax   mpg  engineSize  paintQuality%  previousOwners
# 0       Diesel  145.000000   NaN         2.2           91.0             0.0
# 1       Diesel  145.000000  65.7         2.1           54.0             1.0
# 2       Diesel  145.000000  54.3         2.0           35.0             4.0
# 3       Petrol  145.000000  53.3         1.3           31.0             0.0
# 4       Petrol  290.486785  47.1         1.4           34.0             2.0
# ...        ...         ...   ...         ...            ...             ...
# 75968   Hybrid    0.000000  86.0         1.5           72.0             3.0
# 75969      NaN  125.000000  57.7         2.0            NaN             4.0
# 75970   Petrol  235.000000  39.8         3.0           33.0             2.0
# 75971   Diesel   20.000000  70.6         1.6           37.0             4.0
# 75972   Petrol  145.000000  34.9         1.6           91.0             0.0
#
# [75973 rows x 13 columns]

# %%
X_train = data.drop("price", axis=1)
y_train = data["price"]

# %%
imputer = MissingValuesDealer(imputation_method="knn_modelwise",      
        strategy_cat="most_frequent",            
        knn_neighbors=5,
        random_state=42,
        knn_scaling_method= "standard")

outliers_removel = OutliersDealer()

encoder = EncodingDealer()

scaler = ScalingDealer()

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42
)

# %%
imputer.fit(X_train)
# Out:
# MissingValuesDealer(imputation_method='knn_modelwise')

# %%
imputed_X, imputed_y  = imputer.transform(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 imputed_X, imputed_y  = imputer.transform(X_train, y_train)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File d:\Faculdade\Mestrado\Data Mining\Data Mining_ Materials\ML_Project_Group42\notebooks_2nd_delivery\Preprocessing_pipelines\Missing_Values_pipeline.py:348, in MissingValuesDealer.transform(self, X, y, **kwargs)
#     344 # ----- MODEL-WISE KNN IMPUTATION -----
#     345 elif self.imputation_method == "knn_modelwise":
#     346
#     347     # Impute model first
# --> 348     X["model"] = self.imputer_model.transform(X[["model"]])
#     350     num_cols = X.select_dtypes(include=np.number).columns
#     351     cat_cols = X.select_dtypes(exclude=np.number).columns
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)   4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
#    4539         and value.ndim == 1
#    4540         and not isinstance(value.dtype, ExtensionDtype)
#    4541     ):
#    4542         # broadcast across multiple columns if necessary
#    4543         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:5289, in DataFrame._sanitize_column(self, value)
#    5287 if is_list_like(value):
#    5288     com.require_length_match(value, self.index)
# -> 5289 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5290 if (
#    5291     isinstance(value, Index)
#    5292     and value.dtype == "object"
#    (...)   5295     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5296     # this deprecation
#    5297     warnings.warn(
#    5298         "Setting an Index with object dtype into a DataFrame will stop "
#    5299         "inferring another dtype in a future version. Cast the Index "
#    (...)   5302         stacklevel=find_stack_level(),
#    5303     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\construction.py:604, in sanitize_array(data, index, dtype, copy, allow_2d)
#     602 subarr = data
#     603 if data.dtype == object:
# --> 604     subarr = maybe_infer_to_datetimelike(data)
#     605     if object_index and using_string_dtype() and is_string_dtype(subarr):
#     606         # Avoid inference when string option is set
#     607         subarr = data
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\dtypes\cast.py:1192, in maybe_infer_to_datetimelike(value, convert_to_nullable_dtype)
#    1189     raise TypeError(type(value))  # pragma: no cover
#    1190 if value.ndim != 1:
#    1191     # Caller is responsible
# -> 1192     raise ValueError(value.ndim)  # pragma: no cover
#    1194 if not len(value):
#    1195     return value
#
# ValueError: 2

# %%
imputed_X_val, imputed_y_val  = imputer.transform(X_val, y_val)

# %%
imputed_X_val.isna().sum()
# Out:
# Brand             0
# model             0
# car_age           0
# transmission      0
# mileage           0
# fuelType          0
# tax               0
# mpg               0
# engineSize        0
# paintQuality%     0
# previousOwners    0
# dtype: int64
