# %% [markdown]
# # Cars4You - Handout Project | Group 42
# ## Notebook 0 — Exploratory Data analysis
# **Course:** MSc in Data Science and Advanced Analytics, NOVA IMS (2025/2026)
#
# **Author(s):** Group 42
# - `Miguel Matos - 20221925`
# - `Andre Nicolau - 20221918`
# - `André Ferreira - 20250398`

# %% [markdown]
# ---
#
# #### <font> Table of Contents </font> <a class="anchor" id='toc'></a>
# 1. [Group Member Contribution](#group-member-contribution)
# 2. [Abstract](#abstract)
# 3. [Business Needs](#business-needs)
# 4. [Imports](#Imports)
# 5. [Exploratory Data Analysis](#exploratory-data-analysis)
# - 5.1. [Data Understanding](#data-understanding)
# - 5.2. [Data cleaning](#data-cleaning)
#
#
#     - 5.2.1. [Removing Invalid Entries](#removing-invalid-entries)
#     - 5.2.2. ["brand" variable cleaning](#brand-variable-cleaning)
#     - 5.2.3. ["model" variable cleaning](#model-variable-cleaning)
#     - 5.2.4. ["fuelType" variable cleaning](#fuelType-variable-cleaning)
#     - 5.2.5. ["transmission" variable cleaning](#transmission-variable-cleaning)
#     - 5.2.6. ["Brand" missing values filling](#brand-missing-values-filling)
#
# - 5.3. [Univariate Distributions](#univariate-distributions)
# - 5.4. [Bivariate Distribution](#bivariate-distribution)
#
# ----

# %% [markdown]
# # Group Member Contribution
# [Back to TOC](#toc)

# %% [markdown]
# - Contribution by percentage:
#
# André Ferreira: 33,3%
#
# André Nicolau:  33,3%
#
# Miguel Matos:   33,3%
#
# - What was done by each member:
#
# André Ferreira: Exploratory data analysis, Abstract, Business Needs, encoding pipeline, UI, Models and_params tests, scaling pipeline
#
# André Nicolau: Exploratory data analysis, missing values pipeline, Open ended section, Model_optimization_phase1, functions
#
# Miguel Matos: Exploratory data analysis, outliers pipeline, feature selection pipeline, Model_optimization_phase2, Nuestra pipeline

# %% [markdown]
# # Abstract
# [Back to TOC](#toc)

# %% [markdown]
# Cars 4 You is a used vehicle purchase and reselling company whose current evaluation process requires customers to visit a mechanic before receiving a purchase offer. This procedure introduces delays and discourages potential sellers. To address this limitation, this project aims to develop a machine learning model capable of predicting the price of used cars using only the data provided by customers. Automating the price estimation process is expected to reduce waiting times and support competitiveness in a growing market.
#
# The project was conducted in two main phases. In the first phase, a fully automated preprocessing and modeling pipeline, named NuestraPipeline, was implemented. This custom regression pipeline, fully compatible with scikit-learn, integrates all preprocessing steps and the regression model into a single modular framework. It sequentially applies the preprocessing phase before fitting the final model. During training, observations can be reweighted based on the target price distribution to mitigate bias toward dominant price ranges.
#
# In the second phase, several regression models, such as: Decision Tree, Random Forest, Extra Trees, K-Nearest Neighbors, and HistGradientBoosting were benchmarked using default preprocessing settings and Mean Absolute Error (MAE) as the evaluation metric. Based on these results, the most promising models were selected for further analysis. For each selected model, preprocessing strategies and model hyperparameters were optimized using automated search methods, including Halving Random Search and Bayes Search. The best preprocessing configuration was then fixed per model, followed by a final model tuning stage to obtain optimized parameters.
#
# Overall, tree-based models consistently outperformed distance-based approaches. Among them, HistGradientBoosting achieved the best balance between prediction accuracy and generalization performance. These results demonstrate that an integrated and automated machine learning pipeline can produce reliable price estimates and provide a solid foundation for replacing traditional manual vehicle valuation processes.

# %% [markdown]
# # Business Needs
# [Back to TOC](#toc)

# %% [markdown]
# Identifying Business Needs
#
# - Context:
# The company Cars 4 You specializes in buying and reselling used cars.
# Its current vehicle evaluation process requires customers to visit a mechanic for an in-person inspection before receiving a purchase offer. This process introduces delays, increases operational costs, and discourages potential sellers, negatively impacting the company’s ability to scale and remain competitive in a growing market.
#
# - Business Objective:
# The main objective of this project is to develop a Machine Learning–based solution capable of predicting the purchase price of a used car using only the imputed data provided by the seller, eliminating the need for an initial physical inspection.
#
# - Business Impact:
# By deploying an automated price prediction system, Cars 4 You aims to:
# Reduce customer waiting times;
# Increase the number of vehicles evaluated per day;
# Improve customer satisfaction and retention;
# Strengthen its competitive position in the used-car resale market.
#
# - Problem Formulation:
# From a Machine Learning perspective, the task is formulated as a supervised regression problem, where the goal is to predict the continuous target variable price based on a set of vehicle attributes provided by the user.
#
# - Overall Process and Model Assessment Strategy:
# Historical vehicle data from Cars 4 You’s 2020 database is used to train and validate predictive models. The overall process includes data preprocessing, model training, benchmarking of multiple regression algorithms, and performance comparison.
# To assess model generalization and ensure reliable performance, a train/validation split combined with cross-validation is adopted as the primary model assessment strategy. This approach allows consistent comparison between candidate models while reducing the risk of overfitting and supporting the selection of the most robust solution.

# %% [markdown]
# # Imports
# [Back to TOC](#toc)

# %%
from utils.functions import *
data = pd.read_csv("data/train.csv")
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Data Understanding
# [Back to TOC](#toc)

# %% [markdown]
# This step focuses on exploring the dataset, assessing data quality, and identifying key patterns and relationships. The goal is to ensure a clear understanding of the data and have it cleaned for the next stages of the process

# %%
data.shape
# Out:
# (75973, 14)

# %% [markdown]
# We can oberserve that there are almost 76k rows and only 14 columns.

# %%
data.head()
# Out:
#    carID   Brand      model    year  price transmission  mileage fuelType  \
# 0  69512      VW       Golf  2016.0  22290    Semi-Auto  28421.0   Petrol
# 1  53000  Toyota      Yaris  2019.0  13790       Manual   4589.0   Petrol
# 2   6366    Audi         Q2  2019.0  24990    Semi-Auto   3624.0   Petrol
# 3  29021    Ford     FIESTA  2018.0  12500        anual   9102.0   Petrol
# 4  10062     BMW   2 Series  2019.0  22995       Manual   1000.0   Petrol
#
#      tax        mpg  engineSize  paintQuality%  previousOwners  hasDamage
# 0    NaN  11.417268         2.0           63.0        4.000000        0.0
# 1  145.0  47.900000         1.5           50.0        1.000000        0.0
# 2  145.0  40.900000         1.5           56.0        4.000000        0.0
# 3  145.0  65.700000         1.0           50.0       -2.340306        0.0
# 4  145.0  42.800000         1.5           97.0        3.000000        0.0

# %%
data.tail()
# Out:
#        carID     Brand     model    year  price transmission  mileage  \
# 75968  37194  Mercedes   C Class  2015.0  13498       Manual  14480.0
# 75969   6265      Audi        Q3  2013.0  12495    Semi-Auto  52134.0
# 75970  54886    Toyota      Aygo  2017.0   8399    Automatic  11304.0
# 75971    860      Audi        Q3  2015.0  12990       Manual  69072.0
# 75972  15795      Ford    Fiesta  2018.0  10495       Manual  16709.0
#
#       fuelType    tax   mpg  engineSize  paintQuality%  previousOwners  \
# 75968    etrol  125.0  53.3         2.0           78.0             0.0
# 75969   Diesel  200.0  47.9         2.0           38.0             2.0
# 75970   Petrol  145.0  67.0         1.0           57.0             3.0
# 75971    iesel  125.0  60.1         2.0           74.0             2.0
# 75972    Petro  145.0  64.2         1.1           38.0             1.0
#
#        hasDamage
# 75968        0.0
# 75969        0.0
# 75970        0.0
# 75971        0.0
# 75972        0.0

# %%
data.set_index("carID").sort_index()
# Out:
#       Brand       model    year  price transmission  mileage fuelType    tax  \
# carID
# 0       Aud          A3  2016.0  10990       Manual  57097.0   Diesel    0.0
# 1      Audi          A7  2017.0  22999    Semi-Auto  24337.0   diesel  150.0
# 2      Audi          A4  2016.0  14242       Manual  14900.0   Petrol  125.0
# 3      Audi          Q3  2017.0  15998       Manual  37151.0   Petrol  145.0
# 4       NaN          A6  2019.0  30850    Automatic   4553.0   Diesel  145.0
# ...     ...         ...     ...    ...          ...      ...      ...    ...
# 75968    VW        Golf  2015.0  11299       Manual  24959.0    Petro    NaN
# 75969    VW   Caravelle  2019.0  39950    Automatic   7583.0   Diesel  145.0
# 75970    VW        Golf  2019.0  18995    Automatic   8044.0    Other  145.0
# 75971    VW        golf  2019.0  16650       MANUAL  12900.0   Petrol  145.0
# 75972    VW        Polo  2019.0  14991       Manual   2000.0   Diesel  145.0
#
#         mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 0      83.1         1.6           75.0             4.0        0.0
# 1      55.4         3.0           31.0             0.0        0.0
# 2      53.3         1.4           65.0             4.0        0.0
# 3      51.4         1.4           55.0             1.0        0.0
# 4      47.9         2.0           62.0             0.0        0.0
# ...     ...         ...            ...             ...        ...
# 75968  53.3         1.4           86.0             2.0        0.0
# 75969  32.8         2.0           96.0             2.0        0.0
# 75970  43.5         1.5           80.0             4.0        0.0
# 75971  49.6         1.0           74.0             1.0        0.0
# 75972   NaN         1.6           32.0             4.0        0.0
#
# [75973 rows x 13 columns]

# %% [markdown]
# As the brands are ordered by "carID" variable, we'll put that variable as index and sort it in ascending order.

# %%
data = data.set_index("carID").sort_index()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75973 entries, 0 to 75972
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           74452 non-null  object
#  1   model           74456 non-null  object
#  2   year            74482 non-null  float64
#  3   price           75973 non-null  int64
#  4   transmission    74451 non-null  object
#  5   mileage         74510 non-null  float64
#  6   fuelType        74462 non-null  object
#  7   tax             68069 non-null  float64
#  8   mpg             68047 non-null  float64
#  9   engineSize      74457 non-null  float64
#  10  paintQuality%   74449 non-null  float64
#  11  previousOwners  74423 non-null  float64
#  12  hasDamage       74425 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 8.1+ MB

# %% [markdown]
# There are some missing values, but the dtypes seem to be accordingly.

# %%
data.isna().sum()
# Out:
# Brand             1521
# model             1517
# year              1491
# price                0
# transmission      1522
# mileage           1463
# fuelType          1511
# tax               7904
# mpg               7926
# engineSize        1516
# paintQuality%     1524
# previousOwners    1550
# hasDamage         1548
# dtype: int64

# %% [markdown]
# Let's take a look into descriptive analysis.

# %%
#Non-numeric features analysis
comparison_data = data.describe(exclude=np.number) # This dataset will be used for futher comparisons
data.describe(exclude=np.number)
# Out:
#         Brand   model transmission fuelType
# count   74452   74456        74451    74462
# unique     72     735           40       34
# top      Ford   Focus       Manual   Petrol
# freq    14808    6353        38050    37995

# %% [markdown]
# Insights from non numeric features:
# - "Ford Focus" is the most common car from the dataset, with a frequency of 6353.
#
# Now, let's take a look into the unique values of the categorical features.

# %%
print(f"Unique values of 'Brands':\n\n {data['Brand'].unique()}\n")
print(f"Unique values of 'model':\n\n {data['model'].unique()}\n")
print(f"Unique values of 'transmission':\n\n {data['transmission'].unique()}\n")
print(f"Unique values of 'fuelType':\n\n {data['fuelType'].unique()}\n")
# Out:
# Unique values of 'Brands':
#
#  ['Aud' 'Audi' nan 'audi' 'udi' 'AUDI' 'UDI' 'ud' 'aud' 'AUD' 'BMW' 'MW'
#  'bmw' 'BM' 'mw' 'Ford' 'ford' 'for' 'FORD' 'For' 'ord' 'ORD' 'FOR' 'or'
#  'Hyundai' 'Hyunda' 'yundai' 'hyundai' 'HYUNDAI' 'hyunda' 'HYUNDA' 'yunda'
#  'Mercedes' 'mercedes' 'MERCEDES' 'ercedes' 'Mercede' 'ercede' 'ERCEDES'
#  'MERCEDE' 'mercede' 'Skoda' 'koda' 'SKODA' 'Skod' 'SKOD' 'skoda' 'kod'
#  'skod' 'KODA' 'Toyota' 'toyota' 'TOYOTA' 'Toyot' 'oyota' 'TOYOT' 'OYOTA'
#  'toyot' 'Opel' 'pel' 'opel' 'Ope' 'OPEL' 'OPE' 'PEL' 'ope' 'pe' 'VW' 'W'
#  'v' 'V' 'vw' 'w']
#
# Unique values of 'model':
#
#  ['A3' ' A7' ' A4' ' Q3' ' A6' ' A3' ' A5' ' TT' ' Q7' ' A1' ' Q2' 'A1'
#  ' RS5' ' A8' ' Q5' ' A' ' S4' nan ' Q' ' Q8' ' a3' 'A4' ' a5' ' q7' ' a6'
#  ' RS3' ' RS6' ' RS4' ' q3' ' a4' ' a1' 'Q3' ' RS' ' S3' ' R8' 'A5' 'RS6'
#  ' q5' 'TT' ' S8' 'Q5' ' SQ5' ' q2' 'RS3' 'Q2' ' a7' ' tt' ' a' ' r8' 'A6'
#  'A8' 'Q7' 'a8' ' A2' 'Q8' ' SQ7' ' S5' ' T' ' s3' 'R8' 'A7' ' sq7' 'q5'
#  ' 1 Series' ' 3 Series' ' 2 Series' ' 1 series' ' X1' ' X3' ' X5'
#  '1 Series' ' 5 Series' ' Z4' ' 4 Series' ' X6' ' X2' ' 2 Serie'
#  ' 5 Serie' ' 3 series' ' 6 Series' 'X4' ' X4' ' x5' ' 7 Series'
#  ' 3 Serie' ' M3' ' M4' '2 Series' ' 4 series' ' 2 SERIES' ' i8'
#  ' 5 series' ' X' ' X7' ' M2' ' x1' ' M' ' 3 SERIES' ' 1 SERIES'
#  ' 4 SERIES' '4 Series' ' x' ' 2 series' ' M5' '5 Series' '3 Series'
#  ' 4 Serie' ' 1 Serie' ' x2' ' 1 SERIE' ' Z3' ' 6 series' ' i3' 'X2' 'X5'
#  ' 1 serie' 'X6' ' 6 SERIES' ' Z' ' 8 Series' ' 7 series' 'X7' ' x3'
#  ' 8 SERIES' ' I3' '5 SERIES' ' M6' 'X3' 'Z3' '6 Series' '2 Serie'
#  '1 SERIES' ' 7 SERIES' ' 3 serie' 'M5' ' 2 serie' ' 4 serie' 'X1'
#  ' 5 SERIES' 'x1' 'Z4' ' z4' '4 series' ' 7 Serie' 'M3' ' 8 Serie'
#  ' 8 series' 'i3' ' m4' ' m3' ' i' '1 series' ' 6 Serie' '3 Serie'
#  ' Focus' ' Focu' ' Fiesta' ' Kuga' ' Puma' ' ecosport' ' Ka+' 'Fiesta'
#  ' Edge' ' S-MAX' ' Fusion' ' Fiest' ' EcoSport' ' fiesta' 'Focus'
#  ' C-MAX' ' KA' ' Grand C-MAX' 'Focu' ' Mondeo' ' S-MA' ' focus' 'Mondeo'
#  ' Monde' ' Tourneo Connect' ' B-MAX' ' KUGA' 'Fiest' ' FIESTA' ' Galaxy'
#  ' FOCUS' ' Mustang' 'Ka+' 'Grand C-MAX' ' Grand Tourneo Connect'
#  ' ECOSPORT' ' Tourneo Custom' ' c-max' 'EcoSport' ' C-MA' ' Kug' ' kuga'
#  'Kuga' ' Ka' 'S-MAX' ' B-MA' ' b-max' ' PUMA' ' MONDEO' 'Fusion'
#  ' mondeo' 'C-MAX' ' puma' ' s-max' 'focus' ' GRAND C-MAX' ' edge' 'KA'
#  ' FOCU' ' s-ma' 'B-MAX' ' EcoSpor' 'Tourneo Connect' 'FOCUS' 'fiesta'
#  ' focu' ' Grand C-MA' ' ka' 'Mustang' ' grand c-max' ' Streetka' ' K'
#  'kuga' ' ka+' ' tourneo custom' ' KA+' ' Ranger' ' galaxy' ' EDGE'
#  'Galaxy' ' MONDE' ' GALAXY' 'B-MA' ' Escort' ' Galax' ' mustang' ' Edg'
#  ' Grand Tourneo Connec' ' Tourneo Custo' 'FIESTA' 'ka+'
#  ' tourneo connect' ' I30' ' IX20' ' I10' ' I800' ' Kona' ' Tucson'
#  ' Ioniq' ' I20' 'I40' ' I40' ' Getz' ' i40' ' Santa Fe' ' santa fe'
#  ' IX35' 'Santa Fe' ' TUCSON' ' Tucso' 'Ioniq' 'I10' ' i20' 'Tucson'
#  ' SANTA FE' ' Santa F' 'I20' ' tucson' ' I1' ' kona' 'IX20' ' i30'
#  ' Ioni' ' I2' 'I30' ' i10' ' Terracan' ' I80' ' TUCSO' 'IX35' ' ix20'
#  ' KONA' 'Kona' ' Accent' ' IX2' ' KON' ' Veloste' ' Kon' ' IONIQ' 'Tucso'
#  'IONIQ' ' ix35' ' ioniq' ' C Class' ' SL CLAS' ' SLK' ' GLE Class'
#  ' A Class' ' GLC Class' ' C CLASS' ' E Class' ' E CLASS' ' CL Class'
#  ' B Class' ' SL CLASS' ' GLA Clas' ' GLA Class' ' V Class' ' CLS Class'
#  ' S Class' ' E Clas' ' CLA Class' ' X-CLASS' ' gla class' ' C Clas'
#  ' GL Class' ' e class' ' glc class' ' cla class' 'C Class' ' c class'
#  ' GLC CLASS' ' M Class' ' gle class' ' GLS Class' 'A Class' ' B Clas'
#  ' GLE CLASS' ' GLA CLASS' ' A Clas' ' M CLASS' 'GLC Class' ' G Class'
#  ' CLS CLASS' 'SLK' ' a class' 'E Class' ' A CLASS' ' CL Clas'
#  ' GLB Class' ' CL CLASS' 'GLA Class' ' slk' ' CLC Class' ' x-class'
#  'GLE Class' 'M Class' ' GLC Clas' ' GLE Clas' ' s class' ' sl class'
#  'B Class' ' b class' ' cl class' 'S Class' ' S Clas' 'V Class' '230'
#  '220' 'CLA Class' ' CLK' ' C CLAS' 'b class' ' CLS Clas' ' B CLASS'
#  ' v class' ' glb class' ' GLS CLASS' ' V CLASS' ' X-CLAS' ' GLS Clas'
#  'a class' 'SL CLASS' ' cls class' ' a clas' ' m class' 'c class'
#  'CL Class' 'C Clas' ' S CLASS' ' gls class' ' c clas' ' CLA CLASS'
#  ' gl class' ' SL' ' x-clas' ' V Clas' ' GL CLASS' ' glc clas' 'CLS Class'
#  'CLK' '200' 'E CLASS' 'e class' ' M Clas' 'A CLASS' 'GL Class' ' Fabia'
#  ' Yeti Outdoor' ' Rapid' ' Kodiaq' ' Superb' ' Octavia' 'Fabia' ' Octavi'
#  ' Citigo' ' Karoq' ' Scala' ' Kamiq' 'Karoq' ' Yeti' 'Superb' ' octavia'
#  'Octavia' ' KODIAQ' ' OCTAVIA' ' Karo' ' karoq' ' SUPERB' 'Yeti Outdoor'
#  ' CITIGO' ' kodiaq' ' scala' ' super' ' FABIA' ' Kodia' ' SCALA' ' Fabi'
#  ' Citig' ' yeti' ' rapid' ' yeti outdoor' ' citigo' 'Citigo' ' fabia'
#  ' Yeti Outdoo' 'Roomster' ' Scal' ' YETI OUTDOOR' ' KAMIQ' ' superb'
#  ' Roomster' 'Rapid' 'Octavi' 'kodiaq' 'Kodiaq' 'Scala' ' Super' 'octavia'
#  ' kamiq' 'FABIA' ' Rapi' ' Roomste' ' KAROQ' ' scal' 'Yeti' ' Yet'
#  ' KAMI' ' Yaris' ' Aygo' ' C-HR' ' GT86' ' Ayg' ' Auris' ' RAV4' ' Prius'
#  ' Hilux' ' Hilu' ' Land Cruiser' ' Supra' ' yaris' ' Corolla' ' Yari'
#  'Auris' ' Avensis' ' corolla' ' aygo' ' Auri' ' Verso' ' AYG' ' RAV'
#  ' YARIS' ' Verso-S' 'Prius' ' prius' ' AURIS' ' Urban Cruiser' 'aygo'
#  'RAV4' ' auris' 'Yaris' 'Aygo' ' COROLLA' ' PRIUS' ' AYGO' 'Corolla'
#  ' PROACE VERSO' ' C-H' ' Urban Cruise' ' c-hr' 'rav4' ' gt86' ' hilux'
#  ' Camry' 'C-HR' 'Supra' 'corolla' 'Hilux' ' rav4' ' VERSO' 'Verso' ' rav'
#  ' ayg' ' IQ' ' Vers' ' Land Cruise' ' verso' ' YARI' ' Coroll' ' AVENSIS'
#  'RAV' ' yari' 'Yari' 'yaris' 'Avensis' ' avensis' ' Corsa' ' Astra'
#  ' Crossland X' ' Zafira' ' Mokka X' ' Meriva' ' Insignia' ' Grandland X'
#  ' Viva' 'Mokka' 'ASTRA' 'Astra' ' Mokka' ' Astr' ' corsa' ' astra'
#  'Zafira Tourer' 'Viva' ' GTC' ' ZAFIRA' ' Cors' ' viva' ' Adam' ' ASTRA'
#  'Corsa' ' Vivaro' ' Insigni' ' zafira' 'Mokka X' ' Mokka ' ' CORSA'
#  ' MOKKA X' ' mokka x' ' Combo Life' ' MERIVA' 'Insignia' ' Antara'
#  ' MOKKA' 'Adam' ' Meriv' ' INSIGNIA' ' insignia' 'Zafira' ' cors' ' Mokk'
#  ' Zafira Tourer' ' Crossland ' ' Kadjar' ' Zafir' ' Ada' 'gtc' ' Tigra'
#  ' adam' ' ZAFIRA TOURER' ' CROSSLAND X' ' COMBO LIFE' 'Grandland X'
#  ' meriva' ' mokka' 'Zafir' ' Cascada' ' grandland x' ' Grandland '
#  ' Agila' ' crossland x' ' combo life' 'GTC' ' ADAM' ' GRANDLAND X'
#  ' Zafira Toure' ' gtc' 'Mokk' ' VIVA' ' Vectra' 'Crossland X' ' Viv'
#  ' VECTRA' ' grandland ' 'Mokka ' ' CORS' 'Meriva' ' INSIGNI' 'corsa'
#  'Combo Life' 'astra' ' Combo Lif' 'Insigni' ' mokka ' 'Vectra'
#  'COMBO LIFE' ' Ampera' ' Golf' ' T-Cross' ' Polo' ' Up' ' Tiguan'
#  ' Golf SV' ' Touran' ' GOLF' ' Passat' ' Scirocco' ' T-Roc' ' Touareg'
#  ' polo' ' Sharan' ' Tiguan Allspace' ' Arteon' ' Beetle' ' Golf S' ' Gol'
#  ' CC' ' up' ' Caddy Maxi Life' ' Caravelle' ' golf' ' POLO' 'Up'
#  ' GOLF SV' ' Amarok' ' Pol' ' UP' 'Sharan' 'Golf' 'Polo' ' U'
#  ' caravelle' ' Jetta' ' passat' ' PASSAT' ' t-cross' ' tiguan' ' TIGUAN'
#  ' California' ' Passa' ' T-ROC' ' touareg' 'Tiguan' 'Passat' 'Gol'
#  ' Toura' ' touran' ' scirocco' 'Touareg' ' sharan' ' T-Ro' 'Touran'
#  ' Shara' 'polo' ' Shuttle' 'Arteo' ' Touare' 'Scirocco' ' Tigua' 'POLO'
#  ' t-cros' ' Caddy' ' Eos' ' T-Cros' 'Amarok' ' T-CROSS' ' Caddy Maxi'
#  ' TOUAREG' 'T-Roc' ' Scirocc' 'T-Cross' 'Beetle' ' TIGUAN ALLSPACE'
#  ' amarok' ' JETTA' ' Caravell' 'TIGUAN' 'tiguan' ' SHARAN' ' Beetl'
#  ' Arteo' ' Caddy Life' ' tiguan allspace' 'Golf SV' 'U' ' Tiguan Allspac'
#  ' SCIROCCO' ' golf sv' 'Arteon' 'Tigua' ' t-roc' 'Golf S' ' gol'
#  ' beetle' 'UP' ' T-RO' ' TOURA' ' cc' ' golf s' 'CC' ' Amaro' ' shuttle'
#  ' Fox' 'golf' ' ARTEON' ' Caddy Maxi Lif' ' GOL' ' arteon' 'Toura'
#  ' TOURAN' ' TIGUA' 'Pol']
#
# Unique values of 'transmission':
#
#  ['Manual' 'Semi-Auto' 'Automatic' 'anual' 'manual' 'AUTOMATIC' 'Manua'
#  'emi-Auto' nan 'unknown' 'SEMI-AUTO' 'Semi-Aut' 'nknown' 'Manual '
#  'MANUAL' 'automatic' ' Manual ' 'semi-auto' 'emi-auto' 'Automati'
#  'utomatic' 'anua' 'ANUAL' 'unknow' 'SEMI-AUT' 'UTOMATIC' 'emi-Aut'
#  'MANUA' 'semi-aut' 'EMI-AUTO' 'utomati' 'UNKNOWN' ' Manual' ' MANUAL '
#  'manua' 'AUTOMATI' ' manual ' 'manual ' 'Other' 'automati' 'nknow']
#
# Unique values of 'fuelType':
#
#  ['Diesel' 'diesel' 'Petrol' 'Petro' 'etrol' 'petrol' 'iesel' 'PETROL' nan
#  'DIESEL' 'Diese' 'Hybrid' 'etro' 'ETROL' 'iese' 'PETRO' 'petro' 'ybrid'
#  'diese' 'IESEL' 'Other' 'HYBRID' 'hybrid' 'Hybri' 'DIESE' 'Othe'
#  'Electric' 'ETRO' 'IESE' 'ybri' 'YBRID' 'OTHER' 'ther' 'HYBRI' 'other']

# %% [markdown]
# Through this visualization we can see that there are a lot of type erros in the categorical values, so we'll have to find ways to manage this problem, as we need to access it to have proper data.

# %%
#Numeric features
data.describe(include=np.number)
# Out:
#                year          price        mileage           tax           mpg  \
# count  74482.000000   75973.000000   74510.000000  68069.000000  68047.000000
# mean    2017.096611   16881.889553   23004.184088    120.329078     55.152666
# std        2.208704    9736.926322   22129.788366     65.521176     16.497837
# min     1970.000000     450.000000  -58540.574478    -91.121630    -43.421768
# 25%     2016.000000   10200.000000    7423.250000    125.000000     46.300000
# 50%     2017.000000   14699.000000   17300.000000    145.000000     54.300000
# 75%     2019.000000   20950.000000   32427.500000    145.000000     62.800000
# max     2024.121759  159999.000000  323000.000000    580.000000    470.800000
#
#          engineSize  paintQuality%  previousOwners  hasDamage
# count  74457.000000   74449.000000    74423.000000    74425.0
# mean       1.660136      64.590667        1.994580        0.0
# std        0.573462      21.021065        1.472981        0.0
# min       -0.103493       1.638913       -2.345650        0.0
# 25%        1.200000      47.000000        1.000000        0.0
# 50%        1.600000      65.000000        2.000000        0.0
# 75%        2.000000      82.000000        3.000000        0.0
# max        6.600000     125.594308        6.258371        0.0

# %% [markdown]
# Relevant insights from the numeric features in the dataset:
# - "year" should only cointain integer values and there are values above 2020
#
# - the minimum "mileage" is negative, which doesn't make sense since it represents the amount of miles a car did.
# - the minimum value of "tax" is negative as well and doesn't make sense as well.
# - In "mpg" the minimum being a negative value doesn' make sense as well.
# - The variable "engineSize" shouldn't have negative values also.
# - In "paintQuality%" the maximum value is a value above 100%, which can't be an option as a percentage in this case should be a value between 0 and 100.
# - "previousOwners" variable also has negative values and shouldn't, and also should only contain integer values.
# - "hasDamage" seems to have no values inserted, which might indicates that this column is irrelevant.

# %% [markdown]
# ## Data Cleaning
# Here we addressed data inconsistencies and resolved quality issues detected during the exploration stage. These corrections help ensure a clean and consistent dataset for preprocessing and model training.

# %% [markdown]
# ### Removing Invalid Entries
# [Back to TOC](#toc)

# %% [markdown]
# ##### "year"

# %% [markdown]
# We saw that there are cars that have the year bigger than 2020, and that isn't supposed as it the dataset is from 2020. Let's check how many of those cases we have.

# %%
data[data["year"] > 2020]
# Out:
#       Brand    model         year  price transmission  mileage fuelType  \
# carID
# 102    Audi       A3  2023.605276  18000    Automatic  12607.0   Diesel
# 190    Audi       A3  2023.605276  23290    Automatic  15390.0   Petrol
# 394    Audi       A3  2023.605276  14298       Manual  29709.0   Petrol
# 528    Audi       A4  2023.605276   8480       Manual  72900.0   Diesel
# 684    Audi       A1  2023.605276  10726       Manual  24755.0      NaN
# ...     ...      ...          ...    ...          ...      ...      ...
# 75143    VW     Golf  2023.389822  12488       Manual  46466.0   Petrol
# 75177    VW     Golf  2023.389822  23995     Semi-Aut  11464.0   Diesel
# 75476    VW   Tiguan  2023.389822  12481    Semi-Auto  23379.0   DIESEL
# 75866    VW     Golf  2023.389822  18998       Manual     10.0   Diesel
# 75877    VW    T-Roc  2023.389822  16999       Manual   8074.0   Petrol
#
#          tax   mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 102    145.0  52.3         1.6           44.0             3.0        0.0
# 190    150.0  42.2         1.5           91.0             4.0        0.0
# 394     20.0  60.1         1.4           77.0             0.0        0.0
# 528     30.0  64.2         2.0           67.0             4.0        0.0
# 684      0.0  76.3         1.6           73.0             0.0        0.0
# ...      ...   ...         ...            ...             ...        ...
# 75143   20.0  60.1         1.4           32.0             NaN        0.0
# 75177  145.0  49.6         2.0           55.0             0.0        0.0
# 75476  200.0  47.7         2.0           45.0             3.0        0.0
# 75866  145.0  55.4         1.6           96.0             2.0        0.0
# 75877  145.0  55.4         1.0           43.0             4.0        0.0
#
# [358 rows x 13 columns]

# %% [markdown]
# To solve this issue we will cap the year bigger than 2020 to 2020.

# %%
data["year"] = np.clip(data["year"], 0, 2020)

# %% [markdown]
# This variable should only cointain integer values, but as we can see by the last "describe" method, the max value is a float.

# %%
data["year"] = data["year"].apply(lambda x: math.floor(x) if pd.notna(x) else x)
data["year"].describe()
# Out:
# count    74482.000000
# mean      2017.077361
# std          2.181818
# min       1970.000000
# 25%       2016.000000
# 50%       2017.000000
# 75%       2019.000000
# max       2020.000000
# Name: year, dtype: float64

# %% [markdown]
# Now that this column is cleaned, we'll convert the "year" for "age", as the range of the variable would be the same, but having smaller values, and the model will give more relevance to smaller differences, because a difference of 5 is much more relevant in a variable from 0-50 than from 1970-2020.

# %%
data["year"] = 2020 - data["year"]
data.rename(columns={"year": "car_age"}, inplace= True)
data
# Out:
#       Brand       model  car_age  price transmission  mileage fuelType    tax  \
# carID
# 0       Aud          A3      4.0  10990       Manual  57097.0   Diesel    0.0
# 1      Audi          A7      3.0  22999    Semi-Auto  24337.0   diesel  150.0
# 2      Audi          A4      4.0  14242       Manual  14900.0   Petrol  125.0
# 3      Audi          Q3      3.0  15998       Manual  37151.0   Petrol  145.0
# 4       NaN          A6      1.0  30850    Automatic   4553.0   Diesel  145.0
# ...     ...         ...      ...    ...          ...      ...      ...    ...
# 75968    VW        Golf      5.0  11299       Manual  24959.0    Petro    NaN
# 75969    VW   Caravelle      1.0  39950    Automatic   7583.0   Diesel  145.0
# 75970    VW        Golf      1.0  18995    Automatic   8044.0    Other  145.0
# 75971    VW        golf      1.0  16650       MANUAL  12900.0   Petrol  145.0
# 75972    VW        Polo      1.0  14991       Manual   2000.0   Diesel  145.0
#
#         mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 0      83.1         1.6           75.0             4.0        0.0
# 1      55.4         3.0           31.0             0.0        0.0
# 2      53.3         1.4           65.0             4.0        0.0
# 3      51.4         1.4           55.0             1.0        0.0
# 4      47.9         2.0           62.0             0.0        0.0
# ...     ...         ...            ...             ...        ...
# 75968  53.3         1.4           86.0             2.0        0.0
# 75969  32.8         2.0           96.0             2.0        0.0
# 75970  43.5         1.5           80.0             4.0        0.0
# 75971  49.6         1.0           74.0             1.0        0.0
# 75972   NaN         1.6           32.0             4.0        0.0
#
# [75973 rows x 13 columns]

# %% [markdown]
# ##### "mileage"

# %%
data[data["mileage"] < 0]
# Out:
#       Brand     model  car_age  price transmission       mileage fuelType  \
# carID
# 67     Audi        A5      5.0  16250       Manual -52618.457894   Petrol
# 158    Audi       NaN      1.0  22000    Semi-Auto -52618.457894   Petrol
# 247    Audi        TT     18.0   2876       Manual -52618.457894   Petrol
# 303    Audi        A3      7.0   8990       Manual -52618.457894   Diesel
# 304    Audi        A3      3.0  19995       Manual -52618.457894   Diesel
# ...     ...       ...      ...    ...          ...           ...      ...
# 75549    VW   Golf SV      4.0  11987    Automatic -48190.655673    etrol
# 75723    VW    Sharan      2.0  23642    Semi-Auto -48190.655673   Diesel
# 75771    VW   T-Cross      0.0  18990       Manual -48190.655673   Petrol
# 75891    VW      Golf      2.0  22990    Semi-Auto -48190.655673   Hybrid
# 75961    VW      Golf      4.0  15300    Automatic -48190.655673   Diesel
#
#          tax    mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 67     200.0   42.8         2.0           94.0         4.00000        0.0
# 158    145.0   40.9         2.0           42.0         0.00000        0.0
# 247    295.0   30.1         1.8           69.0         3.00000        0.0
# 303      0.0   74.3         1.6           81.0         4.00000        0.0
# 304    145.0   65.7         2.0           31.0         3.00000        0.0
# ...      ...    ...         ...            ...             ...        ...
# 75549   30.0   54.3         1.4           59.0        -2.34565        0.0
# 75723  145.0   41.5         2.0           36.0         2.00000        0.0
# 75771  145.0   47.9         1.0           49.0         1.00000        0.0
# 75891  140.0  156.9         1.4            NaN         2.00000        0.0
# 75961  125.0   58.9         2.0           75.0         3.00000        0.0
#
# [369 rows x 13 columns]

# %% [markdown]
# As the number of entries from mileage bellow zero is very small compared to the dataset size, we'll assign them as missing values and then take care of those values after some missing values analysis.

# %%
data.loc[data["mileage"] < 0, "mileage"] = np.nan

# %% [markdown]
# ##### "tax"

# %%
data[data["tax"] < 0]
# Out:
#       Brand       model  car_age  price transmission   mileage fuelType  \
# carID
# 46     Audi          A4      2.0  18288    Semi-Auto   31348.0   Petrol
# 268    Audi          A6      NaN  10499    Automatic   92083.0   Diesel
# 632    Audi          Q2      0.0  24988    AUTOMATIC    1500.0   Petrol
# 718    Audi          A4      2.0  30450    Automatic   11775.0   Petrol
# 754    Audi          A4      4.0  18303    Automatic   31817.0   Diesel
# ...     ...         ...      ...    ...          ...       ...      ...
# 75544    VW        Golf      4.0  11495       Manual   36000.0   Petrol
# 75718    VW        Golf      2.0  13749       Manual   26558.0   Diesel
# 75770    VW   Caravelle      8.0  18995    Automatic  102000.0   Diesel
# 75822    VW    Scirocco      4.0  14750       Manual   30989.0   Petrol
# 75838    VW        Golf      4.0   9899       Manual   48675.0   Diesel
#
#              tax   mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 46    -60.684095  51.4    1.400000           82.0        2.000000        0.0
# 268   -60.684095  56.5    2.000000           43.0        1.000000        0.0
# 632   -60.684095  42.2         NaN           72.0       -2.335123        0.0
# 718   -60.684095  37.7    3.000000           51.0        2.000000        0.0
# 754   -60.684095  65.7    2.000000           34.0        4.000000        0.0
# ...          ...   ...         ...            ...             ...        ...
# 75544 -49.153541  53.3    0.186425           40.0        0.000000        0.0
# 75718 -49.153541  57.7    1.600000           46.0        1.000000        0.0
# 75770 -49.153541  34.4    2.000000           78.0        1.000000        0.0
# 75822 -49.153541  46.3    2.000000           46.0        4.000000        0.0
# 75838 -49.153541  74.3    1.600000           85.0        3.000000        0.0
#
# [378 rows x 13 columns]

# %% [markdown]
# The same as "mileage", so we'll assign those values as missing values.

# %%
data.loc[data["tax"] < 0, "tax"] = np.nan

# %% [markdown]
# ##### "mpg"

# %%
print(f" The length of the following dataframe is: {len(data[data['mpg'] < 0])}")
data[data["mpg"] < 0]
# Out:
#  The length of the following dataframe is: 36
#       Brand      model  car_age  price transmission  mileage fuelType    tax  \
# carID
# 7781    BMW   3 Series      3.0  14800       Manual  29968.0   DIESEL   30.0
# 8094    BMW         X3      4.0  15900    Automatic  59692.0   Diesel  145.0
# 8314    BMW   5 Series      6.0  14662    Semi-Auto  59317.0   Diesel   30.0
# 8542    NaN   3 Series      7.0  16291    Semi-Auto  40900.0   Diesel  145.0
# 8691    BMW   1 Series      1.0  17600    Automatic  12839.0   Diesel  145.0
# 8956    BMW   7 series      1.0  55000    Automatic   8546.0   Diesel  145.0
# 9202    BMW         X1      4.0  17000    Automatic  46968.0   Diesel  125.0
# 10078   BMW   6 Series      1.0  31412    Semi-Auto  27713.0   Diesel  145.0
# 10214   BMW   3 Series      6.0  14500    Automatic  45140.0   Diesel  125.0
# 10653   BMW         i3      3.0  19895    Automatic  29851.0   Hybrid    0.0
# 10972   BMW   5 Series      0.0  32995    Semi-Auto     11.0   Hybrid  145.0
# 11143   BMW         Z4      7.0  13640    Semi-Auto  26356.0   Petrol  200.0
# 11181   BMW   1 Series      1.0  19298    Semi-Auto  10040.0   Diesel  145.0
# 11883   BMW   2 Series      1.0  24490    Semi-Auto   9531.0   Diesel  150.0
# 11921    MW   2 Series      3.0  19480      unknown  14612.0   Diesel  145.0
# 12026   BMW   2 Series      2.0  16980       Manual  19853.0   Diesel  150.0
# 12352   BMW         M3      2.0  43990    Semi-Auto  12879.0   Petrol  150.0
# 12400   BMW         X5      4.0  26995    Automatic  46126.0   Diesel  200.0
# 13073    BM   3 Series      5.0  15491    Automatic  35248.0   Diesel   30.0
# 13134   BMW   1 Series      4.0  11941       Manual      NaN   Petrol   30.0
# 13140   BMW   1 Series      1.0  28488    Automatic   6744.0   Petrol    NaN
# 13396   BMW         X1      1.0  25480    Semi-Auto   5163.0   Petrol  145.0
# 13574   BMW   3 Series      3.0  18612    semi-auto  25000.0   Diesel   30.0
# 13698   BMW   3 Series      4.0  13750       Manual  59222.0   Diesel  125.0
# 13713    MW   3 Series      0.0  34900    Automatic    100.0   Diesel  145.0
# 13723   BMW   5 Series      NaN  15499    Automatic  34599.0   Diesel   30.0
# 13855   BMW   3 Series      NaN  20000    Automatic  27725.0   Diesel  145.0
# 13874   BMW   2 Series      6.0  10360    Automatic  45868.0   Petrol  145.0
# 13901   BMW   1 Series      1.0  22890      unknown  10927.0   Petrol  150.0
# 14127   BMW   2 Series      0.0  32450    Semi-Auto   1118.0   Diesel  145.0
# 14420   BMW   2 Series      5.0  17799    Automatic  38902.0   Petrol  260.0
# 14603   BMW   2 Series      5.0  17541    Semi-Auto  26035.0   Petrol  165.0
# 14662   BMW   4 Series      1.0  29631    Automatic    123.0    IESEL  145.0
# 14767   BMW   5 Series      1.0  30001    Semi-Auto  13000.0   Hybrid  140.0
# 14842   BMW         X1      4.0  17225       Manual  17531.0   Diesel  125.0
# 14934   BMW   3 Series      1.0  29500    Automatic   3185.0   Petrol  145.0
#
#              mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 7781  -43.421768         2.0           52.0             1.0        0.0
# 8094  -43.421768         2.0           40.0             4.0        0.0
# 8314  -43.421768         2.0           74.0             4.0        0.0
# 8542  -43.421768         3.0           88.0             NaN        0.0
# 8691  -43.421768         2.0           68.0             1.0        0.0
# 8956  -43.421768         3.0           43.0             0.0        0.0
# 9202  -43.421768         2.0           82.0             0.0        0.0
# 10078 -43.421768         3.0           47.0             1.0        0.0
# 10214 -43.421768         3.0           77.0             2.0        0.0
# 10653 -43.421768         0.0           40.0             0.0        0.0
# 10972 -43.421768         2.0           77.0             2.0        0.0
# 11143 -43.421768         2.0           44.0             4.0        0.0
# 11181 -43.421768         2.0           70.0             3.0        0.0
# 11883 -43.421768         2.0           64.0             4.0        0.0
# 11921 -43.421768         2.0           92.0             2.0        0.0
# 12026 -43.421768         2.0           96.0             3.0        0.0
# 12352 -43.421768         3.0           59.0             1.0        0.0
# 12400 -43.421768         3.0           77.0             2.0        0.0
# 13073 -43.421768         2.0           96.0             3.0        0.0
# 13134 -43.421768         1.5           70.0             2.0        0.0
# 13140 -43.421768         1.5           57.0             3.0        0.0
# 13396 -43.421768         2.0           86.0             1.0        0.0
# 13574 -43.421768         2.0           43.0             0.0        0.0
# 13698 -43.421768         2.0           74.0             1.0        0.0
# 13713 -43.421768         2.0           49.0             4.0        0.0
# 13723 -43.421768         2.0           43.0             3.0        0.0
# 13855 -43.421768         2.0           96.0             1.0        0.0
# 13874 -43.421768         2.0           95.0             0.0        0.0
# 13901 -43.421768         1.5           78.0             4.0        0.0
# 14127 -43.421768         2.0           37.0             1.0        0.0
# 14420 -43.421768         3.0           33.0             4.0        0.0
# 14603 -43.421768         2.0           75.0             3.0        0.0
# 14662 -43.421768         2.0           58.0             0.0        0.0
# 14767 -43.421768         2.0           62.0             4.0        0.0
# 14842 -43.421768         2.0           60.0             2.0        0.0
# 14934 -43.421768         2.0           97.0             3.0        0.0

# %% [markdown]
# This column contains only 36 values bellow zero, and every single one of them belongs to the Brand "BMW", so we'll assign them as missing values and when filling the missing values, we'll probably fill these missing values with the mean or median of BMW's mpg.

# %%
data.loc[data["mpg"] < 0, "mpg"] = np.nan

# %% [markdown]
# ##### "engineSize"

# %%
data[data["engineSize"] < 0]
# Out:
#       Brand    model  car_age  price transmission  mileage fuelType    tax  \
# carID
# 15104  Ford     Focu      4.0   9995       Manual   7905.0   Diesel    NaN
# 15255  Ford    Focus     10.0  29635       Manual   1577.0   Petrol    NaN
# 15492  Ford   Fiesta      2.0  12799       Manual  15526.0   Petrol  145.0
# 15698  Ford    Focus      6.0   6790       Manual  51341.0   Petrol    NaN
# 15972  FORD     Kuga      1.0  21700       Manual  18612.0   Diesel  145.0
# ...     ...      ...      ...    ...          ...      ...      ...    ...
# 29674  Ford    Focus      1.0  18550    Automatic   5016.0   Diesel    NaN
# 30398  Ford   Fiesta      3.0  10020       Manual  15133.0   Petrol   20.0
# 30930  Ford    Focus      5.0   7698       Manual  51060.0   DIESEL   20.0
# 31376  Ford   Fiesta      3.0   7999       Manual  36987.0   Petrol  145.0
# 31390  Ford    Focus      2.0  11491       Manual  36461.0   Diesel  145.0
#
#         mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 15104   NaN   -0.103493           61.0             4.0        0.0
# 15255   NaN   -0.103493           89.0             2.0        0.0
# 15492  62.8   -0.103493           71.0             3.0        0.0
# 15698   NaN   -0.103493           43.0             1.0        0.0
# 15972  47.9   -0.103493           61.0             3.0        0.0
# ...     ...         ...            ...             ...        ...
# 29674  64.2   -0.103493           41.0             0.0        0.0
# 30398  62.8   -0.103493           96.0             4.0        0.0
# 30930  67.3   -0.103493           77.0             3.0        NaN
# 31376  54.3   -0.103493           83.0             4.0        0.0
# 31390  74.3   -0.103493           84.0             4.0        0.0
#
# [84 rows x 13 columns]

# %% [markdown]
# It seems that the negative values of the variable "engineSize" is always correlated with the brand "Ford". Let's check if that's really true.

# %%
data[(data["engineSize"] < 0) & (data["Brand"] != "Ford")]
# Out:
#       Brand    model  car_age  price transmission  mileage fuelType    tax  \
# carID
# 15972  FORD     Kuga      1.0  21700       Manual  18612.0   Diesel  145.0
# 16823   NaN    Focus      5.0   8350       Manual  46935.0   Petrol    NaN
# 20733  FORD    Focus      2.0  11991       Manual  24174.0   Diesel  145.0
# 20920   For     Kuga      3.0  15998       Manual  24024.0   Petrol  150.0
# 23079   For    Focus      NaN  20000       Manual   6156.0   Diesel  145.0
# 24308   NaN   Fiesta      6.0   5995       Manual  59361.0   Petrol    0.0
# 24431   ord      NaN      5.0   6490       Manual  62000.0   Diesel    0.0
# 24953   For    Focus      1.0  17990       Manual   2972.0   Petrol    NaN
# 25300   For    Focus      6.0   6500       Manual  45073.0   Petrol   20.0
# 25855  ford   Mondeo      4.0  12620       Manual  22736.0   Diesel   30.0
# 26383   ORD    C-MAX      3.0  10697      unknown  22870.0   Diesel   20.0
# 28692   ord   Fiesta      2.0  11500       Manual  10500.0   Petrol  150.0
# 28845  FORD    Focus      3.0  11250       Manual  41495.0   Diesel    NaN
#
#         mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 15972  47.9   -0.103493           61.0             3.0        0.0
# 16823   NaN   -0.103493           63.0             4.0        0.0
# 20733  74.3   -0.103493           66.0             4.0        0.0
# 20920  45.6   -0.103493           45.0             0.0        0.0
# 23079  57.7   -0.103493           45.0             1.0        0.0
# 24308  65.7   -0.103493           81.0             1.0        0.0
# 24431  74.3   -0.103493           36.0             0.0        0.0
# 24953   NaN   -0.103493           84.0             4.0        0.0
# 25300  58.9   -0.103493           53.0             0.0        0.0
# 25855  64.2   -0.103493           45.0             1.0        0.0
# 26383  68.9   -0.103493           34.0             3.0        0.0
# 28692  65.7   -0.103493           68.0             3.0        0.0
# 28845   NaN   -0.103493           69.0             3.0        0.0

# %% [markdown]
# Here we have the confirmation that this issue is only related with Ford brand, so we'll assign it as missing values and it could be a good idea to  fill them with some metric related with the Ford brand as we found this pattern.

# %%
data.loc[data["engineSize"] < 0, "engineSize"] = np.nan

# %% [markdown]
# The cases where "engineSize" is equal to 0 don't really make sense as well, let's look at them.

# %%
data.loc[data["engineSize"] ==0]
# Out:
#       Brand    model  car_age  price transmission  mileage fuelType  \
# carID
# 207    Audi       a5      4.0  19000       Manual  26237.0   Diesel
# 227    Audi       Q3      1.0  32788    Automatic   1500.0   Diesel
# 585    Audi       Q3      0.0  37888    AUTOMATIC   1500.0   Petrol
# 672    Audi       Q2      0.0  24990       Manual   1500.0   Petrol
# 694    Audi       Q3      0.0  33444    Automatic   1500.0    etrol
# ...     ...      ...      ...    ...          ...      ...      ...
# 70650    VW    T-Roc      1.0  22000          NaN   2009.0   PETROL
# 71968    VW     Golf      1.0  18000       Manual   5073.0   Petrol
# 72727    VW   Passat      2.0  19500    Automatic  22283.0   Petrol
# 73009    VW   Passat      1.0  18500    Automatic  11993.0   Petrol
# 74510    VW   Tiguan      3.0  19200       Manual  18002.0   Diesel
#
#               tax   mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 207    150.000000  56.5         0.0           66.0             4.0        0.0
# 227    145.000000  47.1         0.0           57.0             4.0        0.0
# 585    145.000000  30.7         0.0           97.0             3.0        0.0
# 672    145.000000  43.5         0.0           77.0             4.0        0.0
# 694    145.000000  31.4         0.0           53.0             0.0        0.0
# ...           ...   ...         ...            ...             ...        ...
# 70650  303.148891  39.8         0.0           80.0             4.0        0.0
# 71968  145.000000  50.4         0.0           54.0             4.0        0.0
# 72727  145.000000  48.7         0.0           54.0             0.0        0.0
# 73009  145.000000  41.5         0.0           89.0             2.0        0.0
# 74510  150.000000  58.9         0.0           97.0             1.0        0.0
#
# [180 rows x 13 columns]

# %% [markdown]
# These cases seem to be more spread apart, so we will transform them in missing values.

# %%
data.loc[data["engineSize"] == 0, "engineSize"] = np.nan

# %% [markdown]
# ##### "paintQuality%"

# %%
data[data["paintQuality%"] > 100]
# Out:
#       Brand    model  car_age  price transmission  mileage fuelType    tax  \
# carID
# 12     Audi       Q3      3.0  20000    Automatic  21981.0   Petrol  145.0
# 73     Audi       Q3      1.0  26925    Semi-Auto   6328.0   Diesel  145.0
# 347    Audi       Q3      1.0  37490    Automatic      NaN   Petrol  145.0
# 1020   Audi       A4      1.0  43990    Automatic   6500.0   Diesel  145.0
# 1146    Aud       Q3      5.0  18500    Automatic  26240.0   Diesel  160.0
# ...     ...      ...      ...    ...          ...      ...      ...    ...
# 74653    VW    Jetta      5.0   8495       Manual  84700.0   Diesel   20.0
# 74665    VW     Polo      1.0  14056       Manual   6000.0   Petrol  145.0
# 74966    VW     Golf      1.0  33750    Semi-Auto   7000.0   Petrol  145.0
# 75161    VW    TIGUA      1.0  34995    Semi-Auto      NaN   Petrol  145.0
# 75768    VW   Tiguan      2.0  18499       Manual  24940.0   Petrol  145.0
#
#         mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 12     47.9         1.4     125.301945             1.0        0.0
# 73     48.7         2.0     125.301945             1.0        0.0
# 347    30.7         2.0     125.301945             0.0        0.0
# 1020   39.2         3.0     125.301945             0.0        0.0
# 1146   50.4         2.0     125.301945             4.0        0.0
# ...     ...         ...            ...             ...        ...
# 74653   NaN         2.0     125.366507             2.0        0.0
# 74665  52.3         1.0     125.366507             2.0        0.0
# 74966  36.2         2.0     125.366507             2.0        0.0
# 75161  35.3         2.0     125.366507             2.0        0.0
# 75768  48.7         1.4     125.366507             0.0        0.0
#
# [367 rows x 13 columns]

# %% [markdown]
# It seems to be the same case as the previous variables, small amount of rows and it isn't related to any specific brand. Will be assigned as missing value and treated in the future.

# %%
data.loc[data["paintQuality%"] > 100, "paintQuality%"]= np.nan

# %% [markdown]
# ##### "previousOwners"

# %%
data[data["previousOwners"] < 0]
# Out:
#       Brand     model  car_age  price transmission  mileage fuelType    tax  \
# carID
# 213    Audi        Q3      1.0  28950    Semi-Auto   4443.0    Petro  145.0
# 230    AUDI        A3      1.0  26290    Semi-Auto   3345.0   Diesel  145.0
# 479    Audi        A1      5.0   8099       Manual  67830.0   Diesel    0.0
# 547    Audi        A1      5.0  10000          NaN  40365.0   Diesel    0.0
# 632    Audi        Q2      0.0  24988    AUTOMATIC   1500.0   Petrol    NaN
# ...     ...       ...      ...    ...          ...      ...      ...    ...
# 75498    VW      Polo      4.0  12495    Semi-Auto   8695.0   Petrol   20.0
# 75542    VW     T-Roc      2.0  17941       Manual  17521.0   petrol  150.0
# 75549    VW   Golf SV      4.0  11987    Automatic      NaN    etrol   30.0
# 75599    VW        Up      5.0   6795       Manual  10800.0   Petrol   20.0
# 75662    VW    Tiguan      3.0  14240       Manual  87000.0   Diesel  150.0
#
#         mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 213    38.2         1.5           49.0       -2.335123        0.0
# 230    51.4         2.0           38.0       -2.335123        0.0
# 479    80.7         1.6           93.0       -2.335123        0.0
# 547    80.7         1.6           80.0       -2.335123        0.0
# 632    42.2         NaN           72.0       -2.335123        0.0
# ...     ...         ...            ...             ...        ...
# 75498  60.1         1.2           61.0       -2.345650        0.0
# 75542  55.4         1.0           51.0       -2.345650        0.0
# 75549  54.3         1.4           59.0       -2.345650        0.0
# 75599  61.4         1.0           31.0       -2.345650        0.0
# 75662  58.9         2.0           49.0       -2.345650        0.0
#
# [371 rows x 13 columns]

# %%
data.loc[data["previousOwners"] < 0, "previousOwners"] = np.nan

# %%
data["previousOwners"] = data["previousOwners"].apply(lambda x: math.floor(x) if pd.notna(x) else x)
data["previousOwners"].describe()
# Out:
# count    74052.000000
# mean         2.015057
# std          1.440985
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: previousOwners, dtype: float64

# %% [markdown]
# Now, there are no negative values on "previousOwners" and all the values are now integers, they were all rounded to the floor value, because we it doesn't make sense to have decimal values in this variable.

# %% [markdown]
# ##### "hasDamage"

# %% [markdown]
# Our dataset does not include any cars explicitly labeled hasdamaged (1), so we aimed to investigate whether the missing values followed any particular pattern. Specifically, we explored whether cars with missing values tended to have very low paint quality and many previous owners, as this might indirectly indicate that those entries should be classified as damaged (1).

# %%
print(f"Previous Owners column where 'hasDamage' is a missing value: \n{data['previousOwners'][data['hasDamage'].isna() == True].describe()}")
print(f"\nNormal Previous Owners column: \n{data['previousOwners'].describe()}")
# Out:
# Previous Owners column where 'hasDamage' is a missing value:
# count    1517.000000
# mean        2.042189
# std         1.472998
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         6.000000
# Name: previousOwners, dtype: float64
#
# Normal Previous Owners column:
# count    74052.000000
# mean         2.015057
# std          1.440985
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: previousOwners, dtype: float64

# %%
print(f"Paint Quality column where 'hasDamage' is a missing value: \n{data['paintQuality%'][data['hasDamage'].isna() == True].describe()}")
print(f"\nNormal Paint Quality column: \n{data['paintQuality%'].describe()}")
# Out:
# Paint Quality column where 'hasDamage' is a missing value:
# count    1513.000000
# mean       64.290631
# std        20.474094
# min         2.725153
# 25%        47.000000
# 50%        64.000000
# 75%        81.000000
# max        99.000000
# Name: paintQuality%, dtype: float64
#
# Normal Paint Quality column:
# count    74082.000000
# mean        64.290118
# std         20.633703
# min          1.638913
# 25%         47.000000
# 50%         64.000000
# 75%         82.000000
# max         99.000000
# Name: paintQuality%, dtype: float64

# %% [markdown]
# Through this visualizations we can see that there is no relevant difference between the missing values and the normal values, so we'll proceed to remove the column, because it only has missing values and 0 zero, so it is of no use for modeling.

# %%
data.drop("hasDamage", axis = 1, inplace= True)

# %% [markdown]
# #### Text normalization for categorical variables cleaning

# %% [markdown]
# In order to be able to plot bar plots for the categorical features in the future, the type errors need to be fixed, otherwise it won't be possible to plot it, as it is in the case of "model" feature, 735 unique values is too much.
#
# As the first step, we'll normalize the text, putting everything in lower case and also eliminating some punctoation and extra spaces.
# We created a function to solve this issue. (normalize_text)

# %%
data["model"] = data["model"].apply(normalize_text)
data["Brand"] = data["Brand"].apply(normalize_text)
data["transmission"] = data["transmission"].apply(normalize_text)
data["fuelType"] = data["fuelType"].apply(normalize_text)

# %%
print(data.describe(exclude=np.number))
print(f"\nUnique values of 'Brands':\n\n {data['Brand'].unique()}\n")
print(f"Unique values of 'model':\n\n {data['model'].unique()}\n")
print(f"Unique values of 'transmission':\n\n {data['transmission'].unique()}\n")
print(f"Unique values of 'fuelType':\n\n {data['fuelType'].unique()}\n")
# Out:
#         Brand  model transmission fuelType
# count   74452  74456        74451    74462
# unique     33    295           17       16
# top      ford  focus       manual   petrol
# freq    15431   6775        40026    39536
#
# Unique values of 'Brands':
#
#  ['aud' 'audi' nan 'udi' 'ud' 'bmw' 'mw' 'bm' 'ford' 'for' 'ord' 'or'
#  'hyundai' 'hyunda' 'yundai' 'yunda' 'mercedes' 'ercedes' 'mercede'
#  'ercede' 'skoda' 'koda' 'skod' 'kod' 'toyota' 'toyot' 'oyota' 'opel'
#  'pel' 'ope' 'pe' 'vw' 'w' 'v']
#
# Unique values of 'model':
#
#  ['a3' 'a7' 'a4' 'q3' 'a6' 'a5' 'tt' 'q7' 'a1' 'q2' 'rs5' 'a8' 'q5' 'a'
#  's4' nan 'q' 'q8' 'rs3' 'rs6' 'rs4' 'rs' 's3' 'r8' 's8' 'sq5' 'a2' 'sq7'
#  's5' 't' '1 series' '3 series' '2 series' 'x1' 'x3' 'x5' '5 series' 'z4'
#  '4 series' 'x6' 'x2' '2 serie' '5 serie' '6 series' 'x4' '7 series'
#  '3 serie' 'm3' 'm4' 'i8' 'x' 'x7' 'm2' 'm' 'm5' '4 serie' '1 serie' 'z3'
#  'i3' 'z' '8 series' 'm6' '7 serie' '8 serie' 'i' '6 serie' 'focus' 'focu'
#  'fiesta' 'kuga' 'puma' 'ecosport' 'ka' 'edge' 's-max' 'fusion' 'fiest'
#  'c-max' 'grand c-max' 'mondeo' 's-ma' 'monde' 'tourneo connect' 'b-max'
#  'galaxy' 'mustang' 'grand tourneo connect' 'tourneo custom' 'c-ma' 'kug'
#  'b-ma' 'ecospor' 'grand c-ma' 'streetka' 'k' 'ranger' 'escort' 'galax'
#  'edg' 'grand tourneo connec' 'tourneo custo' 'i30' 'ix20' 'i10' 'i800'
#  'kona' 'tucson' 'ioniq' 'i20' 'i40' 'getz' 'santa fe' 'ix35' 'tucso'
#  'santa f' 'i1' 'ioni' 'i2' 'terracan' 'i80' 'accent' 'ix2' 'kon'
#  'veloste' 'c class' 'sl clas' 'slk' 'gle class' 'a class' 'glc class'
#  'e class' 'cl class' 'b class' 'sl class' 'gla clas' 'gla class'
#  'v class' 'cls class' 's class' 'e clas' 'cla class' 'x-class' 'c clas'
#  'gl class' 'm class' 'gls class' 'b clas' 'a clas' 'g class' 'cl clas'
#  'glb class' 'clc class' 'glc clas' 'gle clas' 's clas' '230' '220' 'clk'
#  'cls clas' 'x-clas' 'gls clas' 'sl' 'v clas' '200' 'm clas' 'fabia'
#  'yeti outdoor' 'rapid' 'kodiaq' 'superb' 'octavia' 'octavi' 'citigo'
#  'karoq' 'scala' 'kamiq' 'yeti' 'karo' 'super' 'kodia' 'fabi' 'citig'
#  'yeti outdoo' 'roomster' 'scal' 'rapi' 'roomste' 'yet' 'kami' 'yaris'
#  'aygo' 'c-hr' 'gt86' 'ayg' 'auris' 'rav4' 'prius' 'hilux' 'hilu'
#  'land cruiser' 'supra' 'corolla' 'yari' 'avensis' 'auri' 'verso' 'rav'
#  'verso-s' 'urban cruiser' 'proace verso' 'c-h' 'urban cruise' 'camry'
#  'iq' 'vers' 'land cruise' 'coroll' 'corsa' 'astra' 'crossland x' 'zafira'
#  'mokka x' 'meriva' 'insignia' 'grandland x' 'viva' 'mokka' 'astr'
#  'zafira tourer' 'gtc' 'cors' 'adam' 'vivaro' 'insigni' 'combo life'
#  'antara' 'meriv' 'mokk' 'crossland' 'kadjar' 'zafir' 'ada' 'tigra'
#  'cascada' 'grandland' 'agila' 'zafira toure' 'vectra' 'viv' 'combo lif'
#  'ampera' 'golf' 't-cross' 'polo' 'up' 'tiguan' 'golf sv' 'touran'
#  'passat' 'scirocco' 't-roc' 'touareg' 'sharan' 'tiguan allspace' 'arteon'
#  'beetle' 'golf s' 'gol' 'cc' 'caddy maxi life' 'caravelle' 'amarok' 'pol'
#  'u' 'jetta' 'california' 'passa' 'toura' 't-ro' 'shara' 'shuttle' 'arteo'
#  'touare' 'tigua' 't-cros' 'caddy' 'eos' 'caddy maxi' 'scirocc' 'caravell'
#  'beetl' 'caddy life' 'tiguan allspac' 'amaro' 'fox' 'caddy maxi lif']
#
# Unique values of 'transmission':
#
#  ['manual' 'semi-auto' 'automatic' 'anual' 'manua' 'emi-auto' nan 'unknown'
#  'semi-aut' 'nknown' 'automati' 'utomatic' 'anua' 'unknow' 'emi-aut'
#  'utomati' 'other' 'nknow']
#
# Unique values of 'fuelType':
#
#  ['diesel' 'petrol' 'petro' 'etrol' 'iesel' nan 'diese' 'hybrid' 'etro'
#  'iese' 'ybrid' 'other' 'hybri' 'othe' 'electric' 'ybri' 'ther']

# %% [markdown]
# As we can verify, after the text normalization, the number of unique values has already reduced drasticly, but there are still a lot of typos.

# %% [markdown]
# ### "brand" variable cleaning
# [Back to TOC](#toc)

# %%
data["Brand"].unique()
# Out:
# array(['aud', 'audi', nan, 'udi', 'ud', 'bmw', 'mw', 'bm', 'ford', 'for',
#        'ord', 'or', 'hyundai', 'hyunda', 'yundai', 'yunda', 'mercedes',
#        'ercedes', 'mercede', 'ercede', 'skoda', 'koda', 'skod', 'kod',
#        'toyota', 'toyot', 'oyota', 'opel', 'pel', 'ope', 'pe', 'vw', 'w',
#        'v'], dtype=object)

# %% [markdown]
# Here it's possible to clean the unique values left with a dictionary as the names are in order and they aren't a lot of unique values.

# %%
correct_brands = {"Audi": ['aud', 'audi', 'udi', 'ud'],
                  "BMW": ['bmw', 'mw', 'bm'],
                  "Ford": ['ford', 'for', 'ord', 'or'],
                  "Hyundai" : ['hyundai', 'hyunda', 'yundai', 'yunda'],
                  "Mercedes" : ['mercedes','ercedes', 'mercede', 'ercede'],
                  "Skoda": ['skoda', 'koda', 'skod', 'kod'],
                  "Toyota": ['toyota', 'toyot', 'oyota'],
                  "Opel": ['opel', 'pel', 'ope', 'pe'],
                  "VW": ['vw', 'w','v']}

variant_to_brand = {variant: brand for brand, variants in correct_brands.items() for variant in variants}
data["Brand"] = data["Brand"].map(variant_to_brand)
data["Brand"].unique()
# Out:
# array(['Audi', nan, 'BMW', 'Ford', 'Hyundai', 'Mercedes', 'Skoda',
#        'Toyota', 'Opel', 'VW'], dtype=object)

# %%
data["Brand"].value_counts()
# Out:
# Brand
# Ford        16063
# Mercedes    11674
# VW          10385
# Opel         9352
# BMW          7392
# Audi         7325
# Toyota       4622
# Skoda        4303
# Hyundai      3336
# Name: count, dtype: int64

# %% [markdown]
# ### "model" variable cleaning
# [Back to TOC](#toc)

# %% [markdown]
# Firstly, we'll create a dataframe that contains the car models grouped by brand.

# %%
models_per_brand = pd.DataFrame(data.groupby(by =["Brand"])["model"].unique())
models_per_brand["model"] = models_per_brand["model"].apply(lambda x: [model for model in x if pd.notna(model)])
models_per_brand
# Out:
#                                                       model
# Brand
# Audi      [a3, a7, a4, q3, a5, tt, q7, a1, q2, rs5, a8, ...
# BMW       [1 series, 3 series, 2 series, x1, x3, x5, 5 s...
# Ford      [focus, focu, fiesta, kuga, puma, ecosport, ka...
# Hyundai   [i30, ix20, i10, i800, kona, tucson, ioniq, i2...
# Mercedes  [c class, sl clas, slk, gle class, a class, gl...
# Opel      [corsa, astra, crossland x, zafira, mokka x, m...
# Skoda     [fabia, yeti outdoor, rapid, kodiaq, superb, o...
# Toyota    [yaris, aygo, c-hr, gt86, ayg, auris, rav4, pr...
# VW        [golf, t-cross, polo, up, tiguan, golf sv, tou...

# %% [markdown]
# There is a really common typo easy to verify in the "eye test", which is having "clas" instead of class. We'll proceed to correct this typo in order to facilitate the process of finding similar model names.

# %%
models_per_brand["model"] = models_per_brand["model"].apply(lambda x: [re.sub(r'\bclas\b', 'class', str(model)) for model in x])
models_per_brand
# Out:
#                                                       model
# Brand
# Audi      [a3, a7, a4, q3, a5, tt, q7, a1, q2, rs5, a8, ...
# BMW       [1 series, 3 series, 2 series, x1, x3, x5, 5 s...
# Ford      [focus, focu, fiesta, kuga, puma, ecosport, ka...
# Hyundai   [i30, ix20, i10, i800, kona, tucson, ioniq, i2...
# Mercedes  [c class, sl class, slk, gle class, a class, g...
# Opel      [corsa, astra, crossland x, zafira, mokka x, m...
# Skoda     [fabia, yeti outdoor, rapid, kodiaq, superb, o...
# Toyota    [yaris, aygo, c-hr, gt86, ayg, auris, rav4, pr...
# VW        [golf, t-cross, polo, up, tiguan, golf sv, tou...

# %% [markdown]
# In the following cell we standardize car model names within each brand using fuzzy matching. We detect similar model variants with an adaptive similarity threshold, group them under a canonical name, and replace the original values in the dataset. Finally, we capitalize all model names to ensure consistent formatting.

# %%
brands = models_per_brand.index.tolist()

for models, brand in zip(models_per_brand["model"], brands):
    canonical_names = {}  # to store canonical form for each variant

    for model in models:
        if model in canonical_names:
            continue  # already assigned

        # adaptive threshold
        threshold = 90 if len(model) < 4 else 75

        # find similar models within this brand
        matches = process.extract(model, models, scorer=fuzz.token_sort_ratio)
        close = [m for m, score, _ in matches if score >= threshold]
        for c in close:
            canonical_names[c] = model  # group under canonical name

    data.loc[data["Brand"] == brand , "model"] = data.loc[data["Brand"] == brand, "model"].map(canonical_names).fillna(data.loc[data["Brand"] == brand, "model"])

data["model"] = data["model"].str.capitalize()

# %%
#Verifying if the names are correctly changed
canonical_names = {key: value for key, value in canonical_names.items() if key != value}
canonical_names
# Out:
# {'gol': 'golf',
#  'golf s': 'golf sv',
#  't-cros': 't-cross',
#  'pol': 'polo',
#  'tigua': 'tiguan',
#  'toura': 'touran',
#  'passa': 'passat',
#  'scirocc': 'scirocco',
#  't-ro': 't-roc',
#  'touare': 'touareg',
#  'shara': 'sharan',
#  'tiguan allspac': 'tiguan allspace',
#  'arteo': 'arteon',
#  'beetl': 'beetle',
#  'caddy maxi lif': 'caddy maxi life',
#  'caddy maxi': 'caddy maxi life',
#  'caddy life': 'caddy maxi life',
#  'caravell': 'caravelle',
#  'amaro': 'amarok'}

# %%
data.describe(exclude=np.number)
# Out:
#         Brand    model transmission fuelType
# count   74452    74456        74451    74462
# unique      9      226           17       16
# top      Ford  A class       manual   petrol
# freq    16063     7258        40026    39536

# %%
data["model"].unique()
# Out:
# array(['A3', 'A7', 'A4', 'Q3', 'A6', 'A5', 'Tt', 'Q7', 'A1', 'Q2', 'Rs5',
#        'A8', 'Q5', 'A', 'S4', nan, 'Q', 'Q8', 'Rs3', 'Rs6', 'Rs4', 'Rs',
#        'S3', 'R8', 'S8', 'Sq5', 'A2', 'Sq7', 'S5', 'T', '8 series', 'X1',
#        'X3', 'X5', '1 series', 'Z4', '4 series', 'X6', 'X2', '2 serie',
#        '6 series', 'X4', '7 series', 'M3', 'M4', 'I8', '5 series', 'X',
#        'X7', 'M2', 'M', '2 series', 'M5', '3 series', 'Z3', 'I3', 'Z',
#        'M6', 'I', 'Focus', 'Fiesta', 'Kuga', 'Puma', 'Ecosport', 'Ka',
#        'Edge', 'S-max', 'Fusion', 'C-ma', 'Grand c-max', 'Mondeo',
#        'Tourneo connect', 'Galaxy', 'Mustang', 'Tourneo custom', 'Fiest',
#        'C-max', 'Grand c-ma', 'Streetka', 'K', 'Ranger', 'Focu', 'B-max',
#        'Escort', 'I30', 'Ix20', 'I10', 'I800', 'Kona', 'Tucson', 'Ioniq',
#        'I40', 'Getz', 'Santa fe', 'Ix35', 'I1', 'I2', 'Terracan', 'I20',
#        'Accent', 'Veloste', 'A class', 'Sl clas', 'Slk', 'Glb class',
#        'M class', 'C class', 'Sl class', 'Gla clas', 'Cls class',
#        'E clas', 'X-class', 'C clas', 'Cl class', 'E class', 'B clas',
#        'A clas', 'Glc class', 'G class', 'Cl clas', 'S class', 'V class',
#        'Glc clas', 'Gle clas', 'Gla class', 'Gls class', 'Gl class',
#        'S clas', '230', '220', 'Gle class', 'Clk', 'Cls clas', 'B class',
#        'X-clas', 'Gls clas', 'Sl', 'V clas', '200', 'M clas', 'Fabia',
#        'Yeti outdoor', 'Rapid', 'Kodiaq', 'Superb', 'Octavia', 'Citigo',
#        'Karoq', 'Scala', 'Kamiq', 'Yeti', 'Karo', 'Yeti outdoo',
#        'Roomster', 'Scal', 'Yaris', 'Aygo', 'C-hr', 'Gt86', 'Auri',
#        'Rav4', 'Prius', 'Auris', 'Hilux', 'Land cruiser', 'Supra',
#        'Corolla', 'Avensis', 'Verso', 'Proace verso', 'Camry', 'Yari',
#        'Iq', 'Corsa', 'Astra', 'Crossland x', 'Zafira', 'Mokka x',
#        'Meriva', 'Insignia', 'Grandland x', 'Viva', 'Mokk',
#        'Zafira tourer', 'Gtc', 'Adam', 'Combo life', 'Mokka', 'Antara',
#        'Kadjar', 'Tigra', 'Cascada', 'Agila', 'Astr', 'Vectra',
#        'Grandland', 'Vivaro', 'Ampera', 'Golf', 'T-cross', 'Polo', 'Up',
#        'Tiguan', 'Golf sv', 'Touran', 'Passat', 'Scirocco', 'T-roc',
#        'Touareg', 'Sharan', 'Tiguan allspace', 'Arteon', 'Beetle', 'Cc',
#        'Caddy maxi life', 'Caravelle', 'Amarok', 'U', 'Jetta',
#        'California', 'Shuttle', 'Caddy', 'Eos', 'Tigua', 'Fox', 'Gol',
#        'Pol'], dtype=object)

# %%
data["model"].value_counts()
# Out:
# model
# A class     7258
# Focus       6911
# Fiesta      4469
# 8 series    3779
# Golf        3333
#             ...
# Vivaro         1
# Tigua          1
# Fox            1
# Gol            1
# Pol            1
# Name: count, Length: 226, dtype: int64

# %% [markdown]
# ### "fuelType" variable cleaning
# [Back to TOC](#toc)

# %%
data["fuelType"].unique()
# Out:
# array(['diesel', 'petrol', 'petro', 'etrol', 'iesel', nan, 'diese',
#        'hybrid', 'etro', 'iese', 'ybrid', 'other', 'hybri', 'othe',
#        'electric', 'ybri', 'ther'], dtype=object)

# %% [markdown]
# As we don't have a lot of unique values we will correct this variable in the same way as we corrected brand

# %%
correct_fueltype = {"Diesel": ["diesel", "iesel", "diese", "iese"],
                    "Petrol": ["petrol", "petro", "etrol", "etro"],
                    "Hybrid": ["hybrid", "ybrid", "hybri", "ybri"],
                    "Other": ["other", "ther", "othe"],
                    "Eletric": "eletric"}

variant_to_fuelType = {variant: fuelType for fuelType, variants in correct_fueltype.items() for variant in variants}
data["fuelType"] = data["fuelType"].map(variant_to_fuelType)
data["fuelType"].unique()
# Out:
# array(['Diesel', 'Petrol', nan, 'Hybrid', 'Other'], dtype=object)

# %%
data["fuelType"].value_counts()
# Out:
# fuelType
# Petrol    41181
# Diesel    30885
# Hybrid     2225
# Other       167
# Name: count, dtype: int64

# %% [markdown]
# ### "transmission" variable cleaning
# [Back to TOC](#toc)

# %% [markdown]
# As we don't have a lot of unique values we will correct this variable in the same way as we corrected brand

# %%
data["transmission"].unique()
# Out:
# array(['manual', 'semi-auto', 'automatic', 'anual', 'manua', 'emi-auto',
#        nan, 'unknown', 'semi-aut', 'nknown', 'automati', 'utomatic',
#        'anua', 'unknow', 'emi-aut', 'utomati', 'other', 'nknow'],
#       dtype=object)

# %%
correct_transmissions = {
    "Manual": ["manual", "anual", "manua", "anua"],
    "Semi-Auto": ["semi-auto", "emi-auto", "semi-aut", "emi-aut"],
    "Automatic": ["automatic", "automati", "utomatic", "utomati"],
    "Unknown": ["unknown", "unknow", "nknown", "nknow"],"Other": ["other"]}

variant_to_transmissions = {variant: transmissions for transmissions, variants in correct_transmissions.items() for variant in variants}
data["transmission"] = data["transmission"].map(variant_to_transmissions)
data["transmission"].unique()
# Out:
# array(['Manual', 'Semi-Auto', 'Automatic', nan, 'Unknown', 'Other'],
#       dtype=object)

# %%
data["transmission"].value_counts()
# Out:
# transmission
# Manual       41627
# Semi-Auto    16872
# Automatic    15211
# Unknown        736
# Other            5
# Name: count, dtype: int64

# %% [markdown]
# Plotting the data recorded before the cleaning

# %%
comparison_data
# Out:
#         Brand   model transmission fuelType
# count   74452   74456        74451    74462
# unique     72     735           40       34
# top      Ford   Focus       Manual   Petrol
# freq    14808    6353        38050    37995

# %%
data.describe(exclude= np.number)
# Out:
#         Brand    model transmission fuelType
# count   74452    74456        74451    74458
# unique      9      226            5        4
# top      Ford  A class       Manual   Petrol
# freq    16063     7258        41627    41181

# %% [markdown]
# We can verify through this two visualizations, that the unique values of each categorical variable have decreased drastically as a consequence of the data cleaning.

# %% [markdown]
# ### "Brand" missing values filling
# [Back to TOC](#toc)

# %% [markdown]
# In this step we will feel the brand missing values based on the car model, if a model belongs to a certain brand, we know the brand. This step can only be done before splitting the data, because we are not relying on any statistical information or knowledge about the data that would lead to data leakage from the validation dataset.

# %%
brand_per_model = (
    data.groupby("model")["Brand"]
        .unique()                       # get unique brands per model (still lists)
        .apply(lambda x: [b for b in x if pd.notna(b)])  # remove NaNs
        .apply(lambda x: x[0] if len(x) > 0 else None) # take first brand as string
        .to_dict()                        # convert to dictionary
)

brand_per_model
# Out:
# {'1 series': 'BMW',
#  '2 serie': 'BMW',
#  '2 series': None,
#  '200': 'Mercedes',
#  '220': 'Mercedes',
#  '230': 'Mercedes',
#  '3 series': None,
#  '4 series': 'BMW',
#  '5 series': None,
#  '6 series': 'BMW',
#  '7 series': 'BMW',
#  '8 series': 'BMW',
#  'A': 'Audi',
#  'A clas': 'Mercedes',
#  'A class': 'Mercedes',
#  'A1': 'Audi',
#  'A2': 'Audi',
#  'A3': 'Audi',
#  'A4': 'Audi',
#  'A5': 'Audi',
#  'A6': 'Audi',
#  'A7': 'Audi',
#  'A8': 'Audi',
#  'Accent': 'Hyundai',
#  'Adam': 'Opel',
#  'Agila': 'Opel',
#  'Amarok': 'VW',
#  'Ampera': 'Opel',
#  'Antara': 'Opel',
#  'Arteon': 'VW',
#  'Astr': None,
#  'Astra': 'Opel',
#  'Auri': 'Toyota',
#  'Auris': None,
#  'Avensis': 'Toyota',
#  'Aygo': 'Toyota',
#  'B clas': 'Mercedes',
#  'B class': None,
#  'B-max': None,
#  'Beetle': 'VW',
#  'C clas': 'Mercedes',
#  'C class': 'Mercedes',
#  'C-hr': 'Toyota',
#  'C-ma': 'Ford',
#  'C-max': None,
#  'Caddy': 'VW',
#  'Caddy maxi life': 'VW',
#  'California': 'VW',
#  'Camry': 'Toyota',
#  'Caravelle': 'VW',
#  'Cascada': 'Opel',
#  'Cc': 'VW',
#  'Citigo': 'Skoda',
#  'Cl clas': 'Mercedes',
#  'Cl class': None,
#  'Clk': 'Mercedes',
#  'Cls clas': 'Mercedes',
#  'Cls class': 'Mercedes',
#  'Combo life': 'Opel',
#  'Corolla': 'Toyota',
#  'Corsa': 'Opel',
#  'Crossland x': 'Opel',
#  'E clas': 'Mercedes',
#  'E class': None,
#  'Ecosport': 'Ford',
#  'Edge': 'Ford',
#  'Eos': 'VW',
#  'Escort': 'Ford',
#  'Fabia': 'Skoda',
#  'Fiest': None,
#  'Fiesta': 'Ford',
#  'Focu': None,
#  'Focus': 'Ford',
#  'Fox': 'VW',
#  'Fusion': 'Ford',
#  'G class': 'Mercedes',
#  'Galaxy': 'Ford',
#  'Getz': 'Hyundai',
#  'Gl class': None,
#  'Gla clas': 'Mercedes',
#  'Gla class': None,
#  'Glb class': 'Mercedes',
#  'Glc clas': 'Mercedes',
#  'Glc class': None,
#  'Gle clas': 'Mercedes',
#  'Gle class': None,
#  'Gls clas': 'Mercedes',
#  'Gls class': None,
#  'Gol': None,
#  'Golf': 'VW',
#  'Golf sv': 'VW',
#  'Grand c-ma': None,
#  'Grand c-max': 'Ford',
#  'Grandland': None,
#  'Grandland x': 'Opel',
#  'Gt86': 'Toyota',
#  'Gtc': 'Opel',
#  'Hilux': 'Toyota',
#  'I': 'BMW',
#  'I1': 'Hyundai',
#  'I10': 'Hyundai',
#  'I2': 'Hyundai',
#  'I20': None,
#  'I3': 'BMW',
#  'I30': 'Hyundai',
#  'I40': 'Hyundai',
#  'I8': 'BMW',
#  'I800': 'Hyundai',
#  'Insignia': 'Opel',
#  'Ioniq': 'Hyundai',
#  'Iq': 'Toyota',
#  'Ix20': 'Hyundai',
#  'Ix35': 'Hyundai',
#  'Jetta': 'VW',
#  'K': 'Ford',
#  'Ka': 'Ford',
#  'Kadjar': 'Opel',
#  'Kamiq': 'Skoda',
#  'Karo': None,
#  'Karoq': 'Skoda',
#  'Kodiaq': 'Skoda',
#  'Kona': 'Hyundai',
#  'Kuga': 'Ford',
#  'Land cruiser': 'Toyota',
#  'M': 'BMW',
#  'M clas': 'Mercedes',
#  'M class': 'Mercedes',
#  'M2': 'BMW',
#  'M3': 'BMW',
#  'M4': 'BMW',
#  'M5': 'BMW',
#  'M6': 'BMW',
#  'Meriva': 'Opel',
#  'Mokk': 'Opel',
#  'Mokka': None,
#  'Mokka x': 'Opel',
#  'Mondeo': 'Ford',
#  'Mustang': 'Ford',
#  'Octavia': 'Skoda',
#  'Passat': 'VW',
#  'Pol': None,
#  'Polo': 'VW',
#  'Prius': 'Toyota',
#  'Proace verso': 'Toyota',
#  'Puma': 'Ford',
#  'Q': 'Audi',
#  'Q2': 'Audi',
#  'Q3': 'Audi',
#  'Q5': 'Audi',
#  'Q7': 'Audi',
#  'Q8': 'Audi',
#  'R8': 'Audi',
#  'Ranger': 'Ford',
#  'Rapid': 'Skoda',
#  'Rav4': 'Toyota',
#  'Roomster': 'Skoda',
#  'Rs': 'Audi',
#  'Rs3': 'Audi',
#  'Rs4': 'Audi',
#  'Rs5': 'Audi',
#  'Rs6': 'Audi',
#  'S clas': 'Mercedes',
#  'S class': None,
#  'S-max': 'Ford',
#  'S3': 'Audi',
#  'S4': 'Audi',
#  'S5': 'Audi',
#  'S8': 'Audi',
#  'Santa fe': 'Hyundai',
#  'Scal': None,
#  'Scala': 'Skoda',
#  'Scirocco': 'VW',
#  'Sharan': 'VW',
#  'Shuttle': 'VW',
#  'Sl': 'Mercedes',
#  'Sl clas': 'Mercedes',
#  'Sl class': 'Mercedes',
#  'Slk': 'Mercedes',
#  'Sq5': 'Audi',
#  'Sq7': 'Audi',
#  'Streetka': 'Ford',
#  'Superb': 'Skoda',
#  'Supra': 'Toyota',
#  'T': 'Audi',
#  'T-cross': 'VW',
#  'T-roc': 'VW',
#  'Terracan': 'Hyundai',
#  'Tigra': 'Opel',
#  'Tigua': None,
#  'Tiguan': 'VW',
#  'Tiguan allspace': 'VW',
#  'Touareg': 'VW',
#  'Touran': 'VW',
#  'Tourneo connect': 'Ford',
#  'Tourneo custom': 'Ford',
#  'Tt': 'Audi',
#  'Tucson': 'Hyundai',
#  'U': 'VW',
#  'Up': 'VW',
#  'V clas': 'Mercedes',
#  'V class': None,
#  'Vectra': 'Opel',
#  'Veloste': 'Hyundai',
#  'Verso': 'Toyota',
#  'Viva': 'Opel',
#  'Vivaro': None,
#  'X': 'BMW',
#  'X-clas': 'Mercedes',
#  'X-class': 'Mercedes',
#  'X1': 'BMW',
#  'X2': 'BMW',
#  'X3': 'BMW',
#  'X4': 'BMW',
#  'X5': 'BMW',
#  'X6': 'BMW',
#  'X7': 'BMW',
#  'Yari': None,
#  'Yaris': 'Toyota',
#  'Yeti': 'Skoda',
#  'Yeti outdoo': None,
#  'Yeti outdoor': 'Skoda',
#  'Z': 'BMW',
#  'Z3': 'BMW',
#  'Z4': 'BMW',
#  'Zafira': 'Opel',
#  'Zafira tourer': 'Opel'}

# %%
data["Brand"].isna().sum()
# Out:
# np.int64(1521)

# %%
data["Brand"] = data["Brand"].fillna(data["model"].map(brand_per_model))
print(f"We reduced the number of missing values in 'Brand' from 1521 to {data['Brand'].isna().sum()}, which means we filled {1521-data['Brand'].isna().sum()} rows.")
# Out:
# We reduced the number of missing values in 'Brand' from 1521 to 236, which means we filled 1285 rows.

# %% [markdown]
# ## Univariate Distributions
# [Back to TOC](#toc)

# %% [markdown]
# Let's proceed with plotting a histogram for all the variables.

# %%
# Plot ALL Numeric Variables' Histograms in one figure
sns.set(style= "darkgrid")

metric_features = data.select_dtypes(include=np.number).drop("price", axis= 1)

# Prepare figure. Create individual axes where each histogram will be placed
fig, axes = plt.subplots(7, 2, figsize=(15, 20))

# Loop through each feature
for i, feat in enumerate(metric_features):

    # Calculate mean and median
    mean_val = data[feat].mean()
    median_val = data[feat].median()
    
    # Left plot: normal histogram
    axes[i, 0].hist(data[feat], bins = 50, edgecolor= "black", alpha = 0.7)
    axes[i, 0].set_title(f"{feat}")
    axes[i, 0].set_ylabel("Frequency")
    axes[i, 0].axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
    axes[i, 0].axvline(median_val, color='lightgreen', linestyle='-', linewidth=2, label=f'Median: {median_val:.2f}')
    axes[i, 0].legend()

    # Right plot: log-scale histogram
    axes[i, 1].hist(data[feat], bins= 50, log = True, edgecolor= "black", alpha = 0.7)
    axes[i, 1].set_title(f"{feat} (Log Scale)")
    axes[i, 1].axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
    axes[i, 1].axvline(median_val, color='lightgreen', linestyle='-', linewidth=2, label=f'Median: {median_val:.2f}')
    axes[i, 1].legend()

# Adjust layout and add overall title
fig.suptitle("Numeric Variables' Histograms (Normal vs Log Scale)", fontsize=16, y=1.02, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Most relevant take outs from these visualizations:
# - "car_age" feature is a left skewed distribution, in which indicates that most cars are recent and some of them are old. The old cares are possible outliers or meaningful information, so this case needs to be analysed.
#
# - "engineSize" may have some outliers, because values above 3 are quite rare.

# %% [markdown]
# The following step is to plot the boxplot graphs of all features.

# %%
# Plot ALL Numeric Variables' Histograms in one figure

sns.set(style= "darkgrid", context= "notebook") ## Reset to darkgrid

# Prepare figure. Create individual axes where each histogram will be placed
fig, axes = plt.subplots(2, 4, figsize=(15, 10),tight_layout=True)

# Plot data
# Iterate across axes objects and associate each histogram (hint: use the ax.hist() instead of plt.hist()):
for ax, feat in zip(axes.flatten(), metric_features): # Notice the zip() function and flatten() method
    sns.boxplot(x=data[feat], ax=ax)
    
# Layout
# Add a centered title to the figure:
plt.suptitle("Numeric Variables' Box Plots", fontsize=20, y=1.02, fontweight='bold')
plt.show()

# %% [markdown]
# - Through the boxplots we can verify that the variables "car_age", "mileage", "tax", "mpg" and "enigneSize" are quite to very skewed.
#
# - The variables "paintQuality%" and "previousOwners" seem to follow a distribution close to normal distribution.

# %% [markdown]
# ### Analysis of the Target Variable
# [Back to TOC](#toc)

# %%
# Plot ALL Numeric Variables' Histograms in one figure
sns.set(style= "darkgrid")
# Prepare figure. Create individual ax where each histogram will be placed
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

# Loop through each feature

# Calculate mean and median
mean_val = data["price"].mean()
median_val = data["price"].median()
third_quartile = data["price"].quantile(0.75)
    
# Left plot: normal histogram
ax[0].hist(data["price"], bins = 50, edgecolor= "black", alpha = 0.7)
ax[0].set_title(f"price")
ax[0].set_ylabel("Frequency")
ax[0].axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
ax[0].axvline(median_val, color='lightgreen', linestyle='-', linewidth=2, label=f'Median: {median_val:.2f}')
ax[0].axvline(third_quartile, color='lightpink', linestyle='-', linewidth=2, label=f'3rd quartile: {third_quartile:.2f}')
ax[0].legend()

# Right plot: log-scale histogram
ax[1].hist(data["price"], bins= 50, log = True, edgecolor= "black", alpha = 0.7)
ax[1].set_title(f"price (Log Scale)")
ax[1].axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
ax[1].axvline(median_val, color='lightgreen', linestyle='-', linewidth=2, label=f'Median: {median_val:.2f}')
ax[1].axvline(third_quartile, color='lightpink', linestyle='-', linewidth=2, label=f'3rd quartile: {third_quartile:.2f}')
ax[1].legend()

# Adjust layout and add overall title
fig.suptitle("Target variable 'price' distribution", fontsize=16, y=1.02, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Through this visualizations we can verify that the target variable "price" follows a right skewed distribution, containing most of his values in the "average car price", having a median of almost 15k pounds, and the third quartile being equivalent to almost 21k pounds, which means that 75% of this variable values are lower than 21k pounds.
#
# As we can observe from in the left graph and specially in the log scaled graph, in the right, there are still some values of very expensive cars, having some values above 100k pounds.
#
# What this tells us is that a predictive model might stuggle more to predict correctly expensive cars, as the dataset is really skewed to the more "cheap" ones.
#
# This deserves our attention in future work, in order to get a good predictive model even for expensive cars.

# %%
# Plot ALL Numeric Variables' Histograms in one figure

sns.set(style= "darkgrid", context= "notebook") ## Reset to darkgrid
sns.boxplot(x=data["price"])
# Layout
# Add a centered title to the figure:
plt.suptitle("Target variable 'price' distribution", fontsize=20, y=1.02, fontweight='bold')
plt.show()

# %% [markdown]
# Here we can verify what was observed before. It is a very skewed variable, containning a lot of "outliers" representing expensive cars.

# %% [markdown]
# ### Analysis of Categorical Variables

# %%
sns.set(style= "dark")

non_metric_features = data.select_dtypes(exclude= np.number)

fig, axes = plt.subplots(2, 2, figsize=(20, 15))

for ax, feat in zip(axes.flatten(), non_metric_features):
    # use df_deps
    data[feat].value_counts().head(10).plot(kind= "bar", ax=ax)
    ax.set_title(feat, fontsize = 15)
    ax.tick_params(axis='x', rotation=45)
    ax.set_xlabel("")

plt.suptitle("Categorical Variables – Top 10 Frequency values", fontsize=18)
plt.tight_layout()

# %% [markdown]
# From the above plots we can observe that:
#
# - Ford is clearly the brand we have the most cars from, and Hyundai the one we have the fewest.
# - Manual is the most common type of transmission.
# - Petrol and diesel are the most common fuel types. We have more petrol, but the difference compared to diesel is not very large.
# - Cars with other in transmission and fueltype are extremely rare.

# %% [markdown]
# ### Distribution of Models for each Brand

# %%
sns.set(style= "dark")
colors = [
    "#1f77b4",  # blue
    "#ff7f0e",  # orange
    "#2ca02c",  # green
    "#d62728",  # red
    "#9467bd",  # purple
    "#8c564b",  # brown
    "#e377c2",  # pink
    "#7f7f7f",  # gray
    "#17becf"   # cyan
]


fig, axes = plt.subplots(5, 2, figsize=(20, 20))

for ax, brand, color in zip(axes.flatten(), data["Brand"].dropna().unique(), colors):
    
    data["model"][data["Brand"] == brand].value_counts().head(5).plot(kind= "bar", ax=ax, color = color)
    ax.set_title(brand, fontsize = 15)
    ax.tick_params(axis='x', rotation=0)
    ax.set_xlabel("")

plt.suptitle("Top 5 models per Brand", fontsize=18)
plt.tight_layout()

# %% [markdown]
# By the analysis of the plot, the most common model for each brand is:
#
# - Audi - A3
# - BMW - 8 series
# - Ford - Focus
# - Hyundai - Tucson
# - Mercedes - A class
# - Skoda - Fabia
# - Toyota - Yaris
# - Opel - Corsa
# - VW - Golf

# %% [markdown]
# ## Bivariate Distribution
# [Back to TOC](#toc)

# %%
sns.set()

metric_features = data[data.select_dtypes(include=np.number).columns.to_list() + ["Brand"]]

g = sns.pairplot(metric_features, hue= "Brand")

# Mask the upper triangle
for i, j in zip(*np.triu_indices_from(g.axes, 1)):
    g.axes[i, j].set_visible(False)

plt.subplots_adjust(top=0.95)
plt.suptitle("Pairwise Relationship of Numerical Variables", fontsize=20)
plt.show()

# %% [markdown]
# Insights:
#
# - "VW" seems to be the brand that has the cheapest cars and also with lowers quality attributes.
#
# - "Mercedes" and "Audi" seems to be the brand with the most expensive cars.

# %%
#Stack bar chart of Brand and transmission

pd.crosstab(non_metric_features["Brand"], data['transmission']).plot(kind='bar', stacked=True, figsize=(10,6))
plt.legend(title="transmission", loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3)
plt.tight_layout()

plt.show()

# %% [markdown]
# Insights taken by the analysis of the plot:
#
# **Audi**: The transmisson type is fairly distributed by the Audi cars
#
# **BMW**: The transmisson type is fairly distributed by the BMW cars
#
# **Ford**: The majority of ford cars have manual transmission
#
# **Hyundai**: Most of hyundai cars have also manual transmission
#
# **Mercedes**: Most of the cars are either Automatic or semi-auto, they don't have a lot of manual cars
#
# **Opel**: The majority of Opel cars have manual transmission
#
# **Skoda**: The majority of skoda cars have manual transmission
#
# **Toyota**: The majority of skoda cars have manual transmission, and almost no semi-auto
#
# **VW**: More distributed, but the mojority is still manual transmission

# %%
num_per_cat(data, "price", "Brand")

# %% [markdown]
# We can clearly see that Mercedes, Audi and BMW are most expensive Brands

# %%
num_per_cat(data, "engineSize", "Brand")

# %% [markdown]
# It's interesting to see that BMW, Mercedes and Audi are also the brands with the highest engineSize

# %%
metric_features = data.select_dtypes(include= np.number)

correlation_matrix(metric_features, 0.4)

# %% [markdown]
# Insights:
# - "EngineSize" is the most correlated variable with the target variable "price".
# - "Mileage" has a correlation of -0,69 with "price", which means the higher the mileage, the lower the price.

# %%
data.to_csv("data/data_cleaned.csv")
